# %% [markdown]
# Technological Institute of the Philippines | Quezon City - Computer Engineering
# --- | ---
# Course Code: | CPE 311
# Code Title: | Data Science 1 - Computational Thinking with Python
# Summer | 204
# <u>**ASSIGNMENT 6.1** | **Computational Thinking with Python**
# **Name** | Sumilang, Kenneth
# **Section** | CPE22S2
# **Date Performed**: | 6/24/24
# **Date Submitted**: | 6/24/24
# **Instructor**: | Engr. Roman M. Richard
#
# <hr>

# %% [markdown]
# ## Part 1. Steps done in HoA activity

# %% [markdown]
# 0. Import Libraries, Filepath of the dataset

# %%
import pandas as pd
import numpy as np
# Set the file path
file_path = 'alzheimers_disease_data.csv'

# Load the dataset
alzheimers_df = pd.read_csv(file_path)

# %% [markdown]
# 1. Identify the column names

# %%
alzheimers_df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...

# %% [markdown]
# 2. Identify the data types of the data

# %%
alzheimers_df.dtypes
# Out:
# PatientID                      int64
# Age                            int64
# Gender                         int64
# Ethnicity                      int64
# EducationLevel                 int64
# BMI                          float64
# Smoking                        int64
# AlcoholConsumption           float64
# PhysicalActivity             float64
# DietQuality                  float64
# SleepQuality                 float64
# FamilyHistoryAlzheimers        int64
# CardiovascularDisease          int64
# Diabetes                       int64
# Depression                     int64
# HeadInjury                     int64
# Hypertension                   int64
# SystolicBP                     int64
# DiastolicBP                    int64
# CholesterolTotal             float64
# CholesterolLDL               float64
# CholesterolHDL               float64
# CholesterolTriglycerides     float64
# MMSE                         float64
# FunctionalAssessment         float64
# ...

# %% [markdown]
# 3. Display the total number of records

# %%
len(alzheimers_df)
# Out:
# 2149

# %% [markdown]
# 4. Display the first 20 records

# %%
alzheimers_df.head(20)
# Out:
#     PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0        4751   73       0          0               2  22.927749        0
# 1        4752   89       0          0               0  26.827681        0
# 2        4753   73       0          3               1  17.795882        0
# 3        4754   74       1          0               1  33.800817        1
# 4        4755   89       0          0               0  20.716974        0
# 5        4756   86       1          1               1  30.626886        0
# 6        4757   68       0          3               2  38.387622        1
# 7        4758   75       0          0               1  18.776009        0
# 8        4759   72       1          1               0  27.833188        0
# 9        4760   87       0          0               0  35.456302        1
# 10       4761   89       0          3               1  39.463034        0
# 11       4762   78       0          0               2  22.463383        1
# ...

# %% [markdown]
# 5.   Display the last 20 records

# %%
alzheimers_df.tail(20)
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 2129       6880   75       1          1               0  36.569773        0
# 2130       6881   81       1          2               0  22.630945        1
# 2131       6882   79       1          1               0  16.760487        0
# 2132       6883   65       1          0               1  18.517832        0
# 2133       6884   87       0          0               0  35.580967        0
# 2134       6885   62       1          0               1  23.918129        1
# 2135       6886   60       1          0               2  15.435244        0
# 2136       6887   83       1          2               2  19.006926        0
# 2137       6888   86       0          3               0  24.226040        0
# 2138       6889   71       0          0               2  36.796170        0
# 2139       6890   68       0          1               0  17.828965        0
# ...

# %% [markdown]
# 6. Change column name from 'Confusion' to 'Dizzyness' and 'Smoking' to 'Smoker?'

# %%
alzheimers_df.rename(columns={'Confusion': 'Dizzyness'}, inplace=True)
alzheimers_df.rename(columns={'Smoking': 'Smoker?'}, inplace=True)
alzheimers_df.tail(3)
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoker?  \
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  ...  \
# 2146            4.594670          9.886002     8.120025  ...
# 2147            8.674505          6.354282     1.263427  ...
# 2148            7.890703          6.570993     7.941404  ...
#
#       MemoryComplaints  BehavioralProblems       ADL  Dizzyness  \
# 2146                 0                   0  5.036334          0
# 2147                 0                   0  3.785399          0
# 2148                 0                   1  8.327563          0
#
#       Disorientation  PersonalityChanges  DifficultyCompletingTasks  \
# 2146               0                   0                          0
# ...

# %% [markdown]
# 7. Create a new column 'Gender Description' that displays "Male" if the value of Gender is 0, else "Female"

# %%
alzheimers_df.insert(alzheimers_df.columns.get_loc('Gender') + 1, 'Gender Description', alzheimers_df['Gender'].apply(lambda x: 'Male' if x == 0 else 'Female'))
alzheimers_df.tail(3)
# Out:
#       PatientID  Age  Gender Gender Description  Ethnicity  EducationLevel  \
# 2146       6897   77       0               Male          0               1
# 2147       6898   78       1             Female          3               1
# 2148       6899   72       0               Male          0               2
#
#             BMI  Smoker?  AlcoholConsumption  PhysicalActivity  ...  \
# 2146  15.476479        0            4.594670          9.886002  ...
# 2147  15.299911        0            8.674505          6.354282  ...
# 2148  33.289738        0            7.890703          6.570993  ...
#
#       MemoryComplaints  BehavioralProblems       ADL  Dizzyness  \
# 2146                 0                   0  5.036334          0
# 2147                 0                   0  3.785399          0
# 2148                 0                   1  8.327563          0
#
#       Disorientation  PersonalityChanges  DifficultyCompletingTasks  \
# ...

# %% [markdown]
# 8.  Create a new dataframe 'Asian' that gathers data with Alzheimer's (In the Ethnicity column, Asian is coded as '2')

# %%
asian_df = alzheimers_df[(alzheimers_df['Ethnicity'] == 2) & (alzheimers_df['Diagnosis'] == 1)]
asian_df.head(8)
# Out:
#      PatientID  Age  Gender Gender Description  Ethnicity  EducationLevel  \
# 23        4774   82       1             Female          2               1
# 50        4801   81       0               Male          2               2
# 53        4804   61       1             Female          2               0
# 67        4818   63       1             Female          2               2
# 79        4830   89       0               Male          2               2
# 127       4878   60       1             Female          2               0
# 179       4930   75       1             Female          2               3
# 201       4952   65       1             Female          2               2
#
#            BMI  Smoker?  AlcoholConsumption  PhysicalActivity  ...  \
# 23   21.969390        0            3.289650          6.934726  ...
# 50   15.639677        0           15.649190          6.848293  ...
# 53   38.076135        0           19.984018          9.859542  ...
# ...

# %% [markdown]
# 9. Create a new dataframe 'Female' that gathers Female data without Alzheimer's

# %%
female_df = alzheimers_df[(alzheimers_df['Gender'] == 1) & (alzheimers_df['Diagnosis'] == 0)]
female_df.head(8)
# Out:
#     PatientID  Age  Gender Gender Description  Ethnicity  EducationLevel  \
# 3        4754   74       1             Female          0               1
# 5        4756   86       1             Female          1               1
# 8        4759   72       1             Female          1               0
# 12       4763   84       1             Female          0               1
# 14       4765   64       1             Female          0               2
# 22       4773   82       1             Female          0               3
# 26       4777   72       1             Female          0               3
# 30       4781   73       1             Female          0               1
#
#           BMI  Smoker?  AlcoholConsumption  PhysicalActivity  ...  \
# 3   33.800817        1           12.209266          8.428001  ...
# 5   30.626886        0            4.140144          0.211062  ...
# 8   27.833188        0           12.167848          1.531360  ...
# ...

# %% [markdown]
# 10. Create a new dataframe 'African-Americans' that gathers data of all African Americans in the dataset (In the Ethnicity column, African American is coded as '1')

# %%
african_americans_df = alzheimers_df[alzheimers_df['Ethnicity'] == 1]
african_americans_df.head(5)
# Out:
#     PatientID  Age  Gender Gender Description  Ethnicity  EducationLevel  \
# 5        4756   86       1             Female          1               1
# 8        4759   72       1             Female          1               0
# 16       4767   63       1             Female          1               2
# 21       4772   65       0               Male          1               2
# 25       4776   77       0               Male          1               0
#
#           BMI  Smoker?  AlcoholConsumption  PhysicalActivity  ...  \
# 5   30.626886        0            4.140144          0.211062  ...
# 8   27.833188        0           12.167848          1.531360  ...
# 16  22.822896        1            4.433961          7.182895  ...
# 21  37.543943        1           12.063959          9.126038  ...
# 25  39.123677        0            0.953869          8.939249  ...
#
#     MemoryComplaints  BehavioralProblems       ADL  Dizzyness  Disorientation  \
# ...

# %% [markdown]
# 11. Create a new dataframe 'Uneducated' that gathers data of all patients that never finished high school (in the EducationalLevel column, it is coded as '0')

# %%
uneducated_df = alzheimers_df[alzheimers_df['EducationLevel'] == 0]
uneducated_df.head(5)
# Out:
#     PatientID  Age  Gender Gender Description  Ethnicity  EducationLevel  \
# 1        4752   89       0               Male          0               0
# 4        4755   89       0               Male          0               0
# 8        4759   72       1             Female          1               0
# 9        4760   87       0               Male          0               0
# 20       4771   82       1             Female          0               0
#
#           BMI  Smoker?  AlcoholConsumption  PhysicalActivity  ...  \
# 1   26.827681        0            4.542524          7.619885  ...
# 4   20.716974        0           18.454356          6.310461  ...
# 8   27.833188        0           12.167848          1.531360  ...
# 9   35.456302        1           16.028688          6.440773  ...
# 20  36.223099        0            4.192896          6.381502  ...
#
#     MemoryComplaints  BehavioralProblems       ADL  Dizzyness  Disorientation  \
# ...

# %% [markdown]
# 12. Use numpy to get the average age and alcohol consumption

# %%
average_age = np.mean(alzheimers_df['Age'])
average_alcohol_consumption = np.mean(alzheimers_df['AlcoholConsumption'])
print(f'Average Age: {average_age}')
print(f'Average Alcohol Consumption: {average_alcohol_consumption}')
# Out:
# Average Age: 74.90879478827361
# Average Alcohol Consumption: 10.03944170890142

# %% [markdown]
# 13. Use numpy to get the median age and alcohol consumption

# %%
median_age = np.median(alzheimers_df['Age'])
median_alcohol_consumption = np.median(alzheimers_df['AlcoholConsumption'])
print(f'Median Age: {median_age}')
print(f'Median Alcohol Consumption: {median_alcohol_consumption}')
# Out:
# Median Age: 75.0
# Median Alcohol Consumption: 9.934412376241738

# %% [markdown]
# 14. Use numpy to get the middle values of age and alcohol consumption

# %%
middle_age = np.median(alzheimers_df['Age'])
middle_alcohol_consumption = np.median(alzheimers_df['AlcoholConsumption'])
print(f'Middle Age: {middle_age}')
print(f'Middle Alcohol Consumption: {middle_alcohol_consumption}')
# Out:
# Middle Age: 75.0
# Middle Alcohol Consumption: 9.934412376241738

# %% [markdown]
# 15. Use numpy to get the standard deviation of BMI

# %%
std_bmi = np.std(alzheimers_df['BMI'])
print(f'Standard Deviation of BMI: {std_bmi}')
# Out:
# Standard Deviation of BMI: 7.215758640902478

# %% [markdown]
# ## Part 2. Descriptive Statistics and Data Visualizations of Possible Correlations between Alzheimer Diagnosis and other Factors

# %%
# Summary statistics for each numerical variable
summary_stats = alzheimers_df.describe()
print(summary_stats)

# Frequency distribution for categorical variables
gender_distribution = alzheimers_df['Gender'].value_counts()
ethnicity_distribution = alzheimers_df['Ethnicity'].value_counts()
education_level_distribution = alzheimers_df['EducationLevel'].value_counts()

print("\nGender Distribution:")
print(gender_distribution)

print("\nEthnicity Distribution:")
print(ethnicity_distribution)

print("\nEducation Level Distribution:")
print(education_level_distribution)
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2149.000000  2149.000000  2149.000000  2149.000000     2149.000000
# mean   5825.000000    74.908795     0.506282     0.697534        1.286645
# std     620.507185     8.990221     0.500077     0.996128        0.904527
# min    4751.000000    60.000000     0.000000     0.000000        0.000000
# 25%    5288.000000    67.000000     0.000000     0.000000        1.000000
# 50%    5825.000000    75.000000     1.000000     0.000000        1.000000
# 75%    6362.000000    83.000000     1.000000     1.000000        2.000000
# max    6899.000000    90.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoker?  AlcoholConsumption  PhysicalActivity  \
# count  2149.000000  2149.000000         2149.000000       2149.000000
# mean     27.655697     0.288506           10.039442          4.920202
# std       7.217438     0.453173            5.757910          2.857191
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'Diagnosis' to a categorical variable for better plotting
alzheimers_df['Diagnosis'] = alzheimers_df['Diagnosis'].astype('category')

# Plot 1: Ethnicity vs. Diagnosis
plt.figure(figsize=(10, 6))
sns.countplot(x='Ethnicity', hue='Diagnosis', data=alzheimers_df)
plt.title('Ethnicity vs. Diagnosis')
plt.xlabel('Ethnicity')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.grid(True)
plt.show()

# Plot 2: BMI vs. Diagnosis
plt.figure(figsize=(10, 6))
sns.boxplot(x='Diagnosis', y='BMI', data=alzheimers_df)
plt.title('BMI vs. Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('BMI')
plt.grid(True)
plt.show()

# Plot 3: Physical Activity vs. Diagnosis
plt.figure(figsize=(10, 6))
sns.boxplot(x='Diagnosis', y='PhysicalActivity', data=alzheimers_df)
plt.title('Physical Activity vs. Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Physical Activity')
plt.grid(True)
plt.show()

# Plot 4: Education Level vs. Diagnosis
plt.figure(figsize=(10, 6))
sns.countplot(x='EducationLevel', hue='Diagnosis', data=alzheimers_df)
plt.title('Education Level vs. Diagnosis')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.grid(True)
plt.show()

# Plot 5: Alcohol Consumption vs. Diagnosis
plt.figure(figsize=(10, 6))
sns.boxplot(x='Diagnosis', y='AlcoholConsumption', data=alzheimers_df)
plt.title('Alcohol Consumption vs. Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Alcohol Consumption')
plt.grid(True)
plt.show()
