# %% [markdown]
# # Module 7: Data Wrangling with Pandas

# %% [markdown]
# **CPE 311 Computational Thinking with Python**

# %% [markdown]
# Submitted by: Sumilang, Kenneth Ian G.

# %% [markdown]
# Performed on: 7/4/24

# %% [markdown]
# Submitted on: 7/4/24

# %% [markdown]
# Submitted to: Engr. Roman M. Richard

# %% [markdown]
# ## 7.1 Supplementary Activity

# %% [markdown]
# Using the datasets provided, perform the following exercises:

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# We want to look at data for the Facebook, Apple, Amazon, Netflix, and Google (FAANG) stocks, but we were given each as a separate CSV file. Combine them into a single file and store the dataframe of the FAANG data as faang for the rest of the exercises:
#
# 1. Read each file in.
# 2. Add a column to each dataframe, called ticker, indicating the ticker symbol it is for (Apple's is AAPL, for example). This is how you look up a stock. Each file's name is also the ticker symbol, so be sure to capitalize it.
# 3. Append them together into a single dataframe.
# 4. Save the result in a CSV file called faang.csv.

# %%
import pandas as pd

# File names
apple = 'aapl.csv'
amazon = 'amzn.csv'
facebook = 'fb.csv'
google = 'goog.csv'
netflix = 'nflx.csv'

# Read each file into a DataFrame and add the ticker column
df_apple = pd.read_csv(apple)
df_apple['ticker'] = 'AAPL'

df_amazon = pd.read_csv(amazon)
df_amazon['ticker'] = 'AMZN'

df_facebook = pd.read_csv(facebook)
df_facebook['ticker'] = 'FB'

df_google = pd.read_csv(google)
df_google['ticker'] = 'GOOG'

df_netflix = pd.read_csv(netflix)
df_netflix['ticker'] = 'NFLX'

# Append them together into a single DataFrame
faang = pd.concat([df_apple, df_amazon, df_facebook, df_google, df_netflix], ignore_index=True)

# Save the result in a CSV file called faang.csv
faang.to_csv('faang.csv', index=False)

print("FAANG data has been combined and saved to 'faang.csv'.")
# Out:
# FAANG data has been combined and saved to 'faang.csv'.

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# * With faang, use type conversion to change the date column into a datetime and the volume column into integers. Then, sort by date and ticker.
# * Find the seven rows with the highest value for volume.
# * Right now, the data is somewhere between long and wide format. Use melt() to make it completely long format. Hint: date and ticker are our ID variables (they uniquely identify each row). We need to melt the rest so that we don't have separate columns for open, high, low, close, and volume.

# %%
import pandas as pd

# load the FAANG dataset

FAANG = pd.read_csv('faang.csv')

# Convert the 'date' column to 'datetime'

FAANG['date'] = pd.to_datetime(FAANG['date'])

# Convert the 'volume' column to integers.

FAANG['volume'] = FAANG['volume'].astype(int)

# Sort by 'date' and 'ticker'

FAANG = FAANG.sort_values(by=['date','ticker'])

# Find the seven rows with the highest value for 'volume'

top7 = FAANG.nlargest(7, 'volume')

top7
# Out:
#           date      open      high       low     close     volume ticker
# 644 2018-07-26  174.8900  180.1300  173.7500  176.2600  169803668     FB
# 555 2018-03-20  167.4700  170.2000  161.9500  168.1500  129851768     FB
# 559 2018-03-26  160.8200  161.1000  149.0200  160.0600  126116634     FB
# 556 2018-03-21  164.8000  173.4000  163.3000  169.3900  106598834     FB
# 182 2018-09-21  219.0727  219.6482  215.6097  215.9768   96246748   AAPL
# 245 2018-12-21  156.1901  157.4845  148.9909  150.0862   95744384   AAPL
# 212 2018-11-02  207.9295  211.9978  203.8414  205.8755   91328654   AAPL

# %% [markdown]
# #### Melting the DataFrame

# %%
F_LONG = pd.melt(FAANG, id_vars=['date','ticker'],value_vars=['open','high','low','close','volume'])

# Displaying the first few rows of the melted DataFrame
F_LONG
# Out:
#            date ticker variable         value
# 0    2018-01-02   AAPL     open  1.669271e+02
# 1    2018-01-02   AMZN     open  1.172000e+03
# 2    2018-01-02     FB     open  1.776800e+02
# 3    2018-01-02   GOOG     open  1.048340e+03
# 4    2018-01-02   NFLX     open  1.961000e+02
# ...         ...    ...      ...           ...
# 6270 2018-12-31   AAPL   volume  3.500347e+07
# 6271 2018-12-31   AMZN   volume  6.954507e+06
# 6272 2018-12-31     FB   volume  2.462531e+07
# 6273 2018-12-31   GOOG   volume  1.493722e+06
# 6274 2018-12-31   NFLX   volume  1.350892e+07
#
# [6275 rows x 4 columns]

# %% [markdown]
# Exercise 3

# %% [markdown]
# * Using web scraping, search for the list of the hospitals, their address and contact information. Save the list in a new csv file, hospitals.csv.
# * Using the generated hospitals.csv, convert the csv file into pandas dataframe. Prepare the data using the necessary preprocessing techniques.

# %%
# 1. Retrieve PDF
import requests

url = 'https://www.philhealth.gov.ph/partners/providers/institutional/accredited/HOSP_073123.pdf'

req = requests.get(url)

with open('hospitals.pdf','wb') as f:
    f.write(req.content)

# %%
# install library that can extract stuff from a pdf first
# !pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in c:\users\ryzek\anaconda3\lib\site-packages (0.11.1)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\ryzek\anaconda3\lib\site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in c:\users\ryzek\anaconda3\lib\site-packages (from pdfplumber) (9.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\ryzek\anaconda3\lib\site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\ryzek\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\ryzek\anaconda3\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (41.0.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\ryzek\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\ryzek\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.21)

# %%
#2. Extract Data from the pdf
import pdfplumber as pdfile
import pandas as pd

with pdfile.open('hospitals.pdf') as pdf:
    #Extract tables from the first 
    pages = pdf.pages[:106]  # Get the first 106 pages
    tables = [table for page in pages for table in page.extract_tables()]

# %%
tables #display 'tables'
# Out:
# [[['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['CORDILLERA ADMINISTRATIVE REGION',
#    None,
#    None,
#    None,
#    None,
#    '',
#    None,
#    None,
#    None],
#   ['ABRA', None, None, None, None, None, None, None, None],
#   ['1',
#    'ABRA PROVINCIAL HOSPITAL',
#    '50',
#    'LEVEL 1',
#    '0747527509',
#    'abraprovincialhospital@yahoo.c\nom.ph',
#    'CAPITULACION STREET, CALABA',
#    'BANGUED',
#    'G'],
#   ['2',
#    'ASSUMPTA FAMILY HOSPITAL',
#    '17',
#    'LEVEL 1',
#    '09177997644',
#    'assumpta_815@yahoo.com.ph',
#    'MAGALLANES ST., ZONE 5',
#    'BANGUED',
#    'P'],
#   ['3',
#    'BANGUED CHRISTIAN HOSPITAL',
#    '17',
#    'LEVEL 1',
#    '0747525644',
#    'banguedchristianhospital@yaho\no.com.ph',
#    'TORRIJOS STREET, ZONE 5',
#    'BANGUED',
#    'P'],
#   ['4',
#    'DR. PETRONILO V. SEARES SR.\nMEMORIAL HOSPITAL',
#    '24',
#    'LEVEL 1',
#    '09353388157 /\n09677608595',
#    'petronilo_seares@yahoo.com.p\nh',
#    'PEÑARRUBIA ST., ZONE 4',
#    'BANGUED',
#    'P'],
#   ['5',
#    'LA PAZ DISTRICT HOSPITAL',
#    '12',
#    'INF/DISP',
#    '09273096506',
#    'lpdhpho.pga@gmail.com',
#    'POBLACION',
#    'LA PAZ',
#    'G'],
#   ['6',
#    'ST. THERESA WELLNESS CENTER',
#    '12',
#    'INF/DISP',
#    '09778268084',
#    'sttheresawellnesscenter@gmail.\ncom',
#    'BARANGAY TALOGTOG',
#    'DOLORES',
#    'P'],
#   ['7',
#    'VALERA MEDICAL HOSPITAL',
#    '15',
#    'INF/DISP',
#    '0747255595',
#    'valeramed_hospital@yahoo.co\nm',
#    'RIZAL STREET, ZONE 7',
#    'BANGUED',
#    'P'],
#   ['8',
#    'VILLAVICIOSA MEDICARE AND\nCOMMUNITY HOSPITAL',
#    '12',
#    'INF/DISP',
#    '09168911087',
#    'vmchospital2008@yahoo.com.p\nh',
#    'AP-APAYA',
#    'VILLAVICIOSA',
#    'G'],
#   ['APAYAO', None, None, None, None, None, None, None, None],
#   ['9',
#    'AMMA JADSAC DISTRICT HOSPITAL',
#    '18',
#    'INF/DISP',
#    '09161292808',
#    'ajdh.hospital@gmail.com',
#    'BARANGAY POBLACION',
#    'PUDTOL',
#    'G'],
#   ['10',
#    'APAYAO DISTRICT HOSPITAL',
#    '12',
#    'INF/DISP',
#    '09353581439',
#    'adhcalanasan@yahoo.com',
#    'ABASAG ST., POBLACION',
#    'CALANASAN (BAYAG)',
#    'G'],
#   ['11',
#    'APAYAO PROVINCIAL HOSPITAL',
#    '12',
#    'INF/DISP',
#    '09457715427',
#    'aph_kabugao@yahoo.com',
#    'DUCRAO STREET, BARANGAY\nPOBLACION',
#    'KABUGAO',
#    'G'],
#   ['12',
#    'CONNER DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09952093932',
#    'connerdistricthospital@yahoo.c\nom',
#    'RIPANG',
#    'CONNER',
#    'G'],
#   ['13',
#    'FAR NORTH LUZON GENERAL\nHOSPITAL AND TRAINING CENTER',
#    '164',
#    'LEVEL 2',
#    '0746340074',
#    'fnlghtc@yahoo.com.ph',
#    'BRGY. QUIRINO',
#    'LUNA',
#    'G'],
#   ['14',
#    'FLORA DISTRICT HOSPITAL',
#    '12',
#    'INF/DISP',
#    '09287301508',
#    'floradisthosp@gmail.com',
#    'BAGUTONG',
#    'FLORA',
#    'G'],
#   ['15',
#    'STA. MARCELA DISTRICT HOSPITAL',
#    '12',
#    'INF/DISP',
#    '09177703602',
#    'smdh1975@gmail.com /\nsmdh1975@yahoo.com.ph',
#    'SAN CARLOS',
#    'STA. MARCELA',
#    'G'],
#   ['BENGUET', None, None, None, None, None, None, None, None],
#   ['16',
#    'ATOK DISTRICT HOSPITAL',
#    '15',
#    'LEVEL 1',
#    '09209507875',
#    'benguet_adh@yahoo.com',
#    'SAYANGAN, PAOAY',
#    'ATOK',
#    'G'],
#   ['17',
#    'BAGUIO GENERAL HOSPITAL AND\nMEDICAL CENTER',
#    '600',
#    'LEVEL 3',
#    '0746617932',
#    'mcc@bghmc.doh,gov.ph',
#    'GOVERNOR PACK ROAD,',
#    'BAGUIO CITY',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['18',
#    'BAGUIO MEDICAL CENTER',
#    '17',
#    'LEVEL 1',
#    '0744423338',
#    'bmc68claridad@yahoo.com',
#    'NO. 9 MILITARY CUT-OFF ROAD',
#    'BAGUIO CITY',
#    'P'],
#   ['19',
#    'BENGUET GENERAL HOSPITAL',
#    '150',
#    'LEVEL 2',
#    '0744224722',
#    'beghmail.admn@yahoo.com',
#    'KM. 5, PICO',
#    'LA TRINIDAD',
#    'G'],
#   ['20',
#    'CAMP BADO DANGWA HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09957846724',
#    'pnphs_cor@yahoo.com',
#    'CAMP MAJOR BADO DANGWA,\nALAPANG',
#    'LA TRINIDAD',
#    'G'],
#   ['21',
#    'CORDILLERA HOSPITAL OF THE\nDIVINE GRACE INC.',
#    '74',
#    'LEVEL 2',
#    '0746205692 /\n09399253506',
#    'info@cordillerahospital.com',
#    'MB-73 PUGUIS',
#    'LA TRINIDAD',
#    'P'],
#   ['22',
#    'DENNIS MOLINTAS DISTRICT\nHOSPITAL',
#    '10',
#    'LEVEL 1',
#    '09462366462 /\n09082902428',
#    'dmmhbenguet@gmail.com',
#    'DACLAN',
#    'BOKOD',
#    'G'],
#   ['23',
#    'DIVINE PROVIDENCE INFIRMARY\nAND DIAGNOSTIC CENTER',
#    '4',
#    'INF/DISP',
#    '09207295946',
#    'dpidccacop71618@gmail.com',
#    'ALS BUILDING, HALSEMA\nHIGHWAY, ACOP, CAPONGA',
#    'TUBLAY',
#    'P'],
#   ['24',
#    'FORT DEL PILAR STATION HOSPITAL',
#    '12',
#    'INF/DISP',
#    '0744473686 loc 6672',
#    'fdpsh.pmash@gmail.com',
#    'PHILIPPINE MILITARY\nACADEMY, FORT GEN.\nGREGORGIO DEL PILAR',
#    'BAGUIO CITY',
#    'G'],
#   ['25',
#    'ITOGON DISTRICT HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09257891546',
#    'itogonmunicpalhospital@gmail.\ncom',
#    'KERENG, TINONGDAN',
#    'ITOGON',
#    'G'],
#   ['26',
#    'KAPANGAN DISTRICT HOSPITAL',
#    '15',
#    'INF/DISP',
#    '09212322823',
#    'kmch_kapangan@yahoo.com.p\nh',
#    '161 CENTRAL',
#    'KAPANGAN',
#    'G'],
#   ['27',
#    'LEPANTO CONSOLIDATED MINING\nCOMPANY HOSPITAL',
#    '12',
#    'INF/DISP',
#    '09213143503',
#    'lcmc.hospital@lepantomining.c\nom',
#    'LEPANTO, PACO',
#    'MANKAYAN',
#    'P'],
#   ['28',
#    'LUTHERAN HOSPITAL INC.',
#    '18',
#    'LEVEL 1',
#    '09504886669',
#    'lutheranhospital@yahoo.com',
#    '001-UT LUTHERAN COMPOUND,\nABATAN',
#    'BUGUIAS',
#    'P'],
#   ['29',
#    'NORTHERN BENGUET DISTRICT\nHOSPITAL',
#    '15',
#    'INF/DISP',
#    '09084684680 /\n09304559926',
#    'nbdh@benguet.gov.ph',
#    'BEKES, BUYACAOAN',
#    'BUGUIAS',
#    'G'],
#   ['30',
#    'NOTRE DAME DE CHARTRES\nHOSPITAL',
#    '125',
#    'LEVEL 2',
#    '0744243361 to 63 loc 63',
#    'admin@notredamebaguio.com',
#    '25 GENERAL LUNA ROAD',
#    'BAGUIO CITY',
#    'P'],
#   ['31',
#    "PINES CITY DOCTORS' HOSPITAL",
#    '110',
#    'LEVEL 2',
#    '0744453020',
#    'pcdh_mail@yahoo.com',
#    'MAGSAYSAY AVENUE',
#    'BAGUIO CITY',
#    'P'],
#   ['32',
#    'SAINT LOUIS UNIVERSITY - SACRED\nHEART MEDICAL CENTER',
#    '120',
#    'LEVEL 3',
#    '0744425700',
#    'hosp.admin@slu.edu.ph',
#    'ASSUMPTION ROAD EXTENSION',
#    'BAGUIO CITY',
#    'P'],
#   ['33',
#    'STO. NIÑO HOSPITAL OF PHILEX\nMINING CORPORATION',
#    '17',
#    'INF/DISP',
#    '09999926307 LOC 5388',
#    'mlventenilla@philexmining.co\nm.ph',
#    'SITIO PADCAL, CAMP 3',
#    'TUBA',
#    'P'],
#   ['IFUGAO', None, None, None, None, None, None, None, None],
#   ['34',
#    "AGUINALDO PEOPLE'S HOSPITAL",
#    '10',
#    'INF/DISP',
#    '0917578424',
#    'aguinaldo_ph@yahoo.com',
#    'NGAWNGAW, TALITE',
#    'AGUINALDO',
#    'G'],
#   ['35',
#    'DR. TOMAS SR. AND MARIA QUILANG\nMEDICAL AND MATERNITY CLINIC',
#    '8',
#    'INF/DISP',
#    '09773031608',
#    'dtsmqmmc1@gmail.com',
#    'POBLACION WEST',
#    'LAMUT',
#    'P'],
#   ['36',
#    'GOOD NEWS CLINIC AND HOSPITAL',
#    '5',
#    'INF/DISP',
#    '09759165249',
#    'gnchphic@yahoo.com /\ngnchbanaue@gmail.com',
#    'ILOGUE, TAM-AN',
#    'BANAUE',
#    'P']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['37',
#    'HUNGDUAN MUNICIPAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09063381620',
#    'hungduanmunicipalhospital@y\nahoo.com.ph',
#    'MABAKA, HAPAO',
#    'HUNGDUAN',
#    'G'],
#   ['38',
#    'MAYOYAO DISTRICT HOSPITAL',
#    '18',
#    'INF/DISP',
#    '09973443350 /\n09092542414',
#    'mayoyaohospital@gmail.com',
#    'ACACOY, BATO-ALATBANG',
#    'MAYOYAO',
#    'G'],
#   ['39',
#    'PANOPDOPAN DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09276886699',
#    'panopdistricthosp@gmail.com',
#    'BANNIT STREET, MABATOBATO',
#    'LAMUT',
#    'G'],
#   ['40',
#    'POTIA DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09175741414',
#    'potiadisthospital@yahoo.com.p\nh',
#    'STA. MARIA',
#    'ALFONSO LISTA\n(POTIA)',
#    'G'],
#   ['41',
#    'TINOC DISTRICT HOSPITAL',
#    '18',
#    'INF/DISP',
#    '09068759701',
#    'tinocdistricthospital@yahoo.co\nm',
#    'PANTAL, BARANGAY IMPUGONG',
#    'TINOC',
#    'G'],
#   ['KALINGA', None, None, None, None, None, None, None, None],
#   ['42',
#    'ALMORA GENERAL HOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09996963027',
#    'almorageneralhospital@yahoo.c\nom',
#    'SILAO ST., PUROK 4, BULANAO',
#    'TABUK',
#    'P'],
#   ['43',
#    'ANNAH KALIYAH BAAC HOSPITAL',
#    '18',
#    'INF/DISP',
#    '0746242365',
#    'akbhospital31422@gmail.com',
#    '63 PROVINCIAL ROAD DAGUPAN\nCENTRO',
#    'TABUK',
#    'P'],
#   ['44',
#    'HOLY TRINITY MEDICAL CLINIC',
#    '30',
#    'LEVEL 1',
#    '09289390259',
#    'htmcbulanao@yahoo.com',
#    'PUROK 6, BULANAO',
#    'TABUK',
#    'P'],
#   ['45',
#    'JUAN M. DUYAN MEMORIAL\nDISTRICT HOSPITAL',
#    '18',
#    'INF/DISP',
#    '09272803388',
#    'juanmduyan2019@gmail.com',
#    'BABALAG WEST',
#    'RIZAL (LIWAN)',
#    'G'],
#   ['46',
#    'KALINGA DISTRICT HOSPITAL',
#    '18',
#    'INF/DISP',
#    '09563977778',
#    'kdhlubuagan@gmail.com',
#    'TANGADAN, POBLACION',
#    'LUBUAGAN',
#    'G'],
#   ['47',
#    'KALINGA GABRIELA MIJA KIM\nMEDICAL CENTER',
#    '12',
#    'INF/DISP',
#    '09177708131',
#    'ruthduguiang2019@gmail.com',
#    'AGBANNAWAG',
#    'TABUK',
#    'G'],
#   ['48',
#    'KALINGA PROVINCIAL HOSPITAL',
#    '100',
#    'LEVEL 1',
#    '09154650253',
#    'kphkalinga.gov@gmail.com',
#    'PUROK 6, BULANAO',
#    'TABUK',
#    'G'],
#   ['49',
#    'PINUKPUK DISTRICT HOSPITAL',
#    '18',
#    'INF/DISP',
#    '09194875424',
#    'veronicabayong252@gmail.com',
#    'HILLTOP, PINUKPUK JUNCTION',
#    'PINUKPUK',
#    'G'],
#   ['50',
#    'SAN JUAN GENERAL HOSPITAL',
#    '18',
#    'LEVEL 1',
#    '0746277136',
#    'sjgh2019@yahoo.com',
#    'PUROK 5, SAN JUAN',
#    'TABUK',
#    'P'],
#   ['51',
#    "ST. JUDE'S MULTISPECIALTY\nHOSPITAL INC.",
#    '12',
#    'INF/DISP',
#    '09985334566',
#    'stjudeshw@gmail.com',
#    '9 MABINI ST., DAGUPAN WEST',
#    'TABUK',
#    'P'],
#   ['52',
#    'ST. PETER CLAVER HOSPITAL',
#    '30',
#    'LEVEL 1',
#    '0746241911 /\n09959857717',
#    'stpetertabuk@gmail.com',
#    'NO. 12 GENERAL LUNA STREET,\nDAGUPAN CENTRO',
#    'TABUK',
#    'P'],
#   ['53',
#    'WESTERN KALINGA DISTRICT\nHOSPITAL',
#    '25',
#    'INF/DISP',
#    '09365360685 /\n09175611029',
#    'hospbalbalan@gmail.com',
#    'POBLACION',
#    'BALBALAN',
#    'G'],
#   ['MOUNTAIN PROVINCE', None, None, None, None, None, None, None, None],
#   ['54',
#    'ANASTACIA RAFAEL SAGEL\nMEMORIAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09128614729',
#    'arsmh2017@yahoo.com',
#    'POBLACION',
#    'NATONIN',
#    'G'],
#   ['55',
#    'BARLIG DISTRICT HOSPITAL',
#    '17',
#    'INF/DISP',
#    '09663374315',
#    'bardh1964@yahoo.com',
#    'GAWANA',
#    'BARLIG',
#    'G'],
#   ['56',
#    'BESAO DISTRICT HOSPITAL',
#    '17',
#    'LEVEL 1',
#    '09509568300',
#    'bedh_besao@yahoo.com',
#    'BARANGAY KIN-IWAY',
#    'BESAO',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['57',
#    'BONTOC GENERAL HOSPITAL',
#    '100',
#    'LEVEL 1',
#    '09984648544',
#    'bontocgeneralhospital@gmail.c\nom',
#    'MALIGCONG ROAD, UPPER\nCALUTTIT',
#    'BONTOC',
#    'G'],
#   ['58',
#    'LUIS HORA MEMORIAL REGIONAL\nHOSPITAL',
#    '200',
#    'LEVEL 2',
#    '09190066588',
#    'lhmrh_doh@yahoo.com',
#    'ABATAN',
#    'BAUKO',
#    'G'],
#   ['59',
#    'PARACELIS DISTRICT HOSPITAL',
#    '17',
#    'LEVEL 1',
#    '09209604047',
#    'paracelisdistricthospital@gmail.\ncom',
#    'POBLACION',
#    'PARACELIS\n(PARACALES)',
#    'G'],
#   ['60',
#    'THE ST. THEODORE OF TARSUS\nHOSPITAL FOUNDATION INC.',
#    '17',
#    'LEVEL 1',
#    '09209174672',
#    'sth_tarsus@yahoo.com /\npennydomogo@gmail.com',
#    'PATAY',
#    'SAGADA',
#    'P'],
#   ['REGION I', None, None, None, None, '', None, None, None],
#   ['ILOCOS NORTE', None, None, None, None, None, None, None, None],
#   ['61',
#    'BANGUI DISTRICT HOSPITAL',
#    '23',
#    'LEVEL 1',
#    '09163528708/6003270',
#    'banguidh@gmail.com',
#    'ABACA',
#    'BANGUI',
#    'G'],
#   ['62',
#    'BUMANGLAG SPECIALTY HOSPITAL',
#    '11',
#    'INF/DISP',
#    '077-617-1572/0919-\n8218626',
#    'bumanglagspecialtyhospital201\n2@gmail.com',
#    '35 BILLOCA',
#    'BATAC',
#    'P'],
#   ['63',
#    'DINGRAS DISTRICT HOSPITAL',
#    '18',
#    'INF/DISP',
#    '(077)600-\n3085/09088740031',
#    'dingrashospital@yahoo.com.ph',
#    'NATIONAL ROAD, BRGY. SUYO',
#    'DINGRAS',
#    'G'],
#   ['64',
#    'DOÑA JOSEFA EDRALIN MARCOS\nDISTRICT HOSPITAL',
#    '18',
#    'INF/DISP',
#    '09778345332',
#    'DJEMDH@yahoo.com.ph',
#    'BRGY. LYDIA',
#    'MARCOS',
#    'G'],
#   ['65',
#    'DR. BONIFACIA V. ALBANO\nMEMORIAL HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '077-670-3142',
#    'bmc_1970@yahoo.com',
#    'NATIONAL HIGHWAY,BARANGAY\n# 21 LIBTONG',
#    'BACARRA',
#    'P'],
#   ['66',
#    'GAOAT HOSPITAL',
#    '16',
#    'LEVEL 1',
#    '077-600-0450',
#    'gaoatgeneralhospital@gmail.co\nm',
#    'CASTRO ST. BRGY 11, BEN-AGAN,',
#    'BATAC',
#    'P'],
#   ['67',
#    'GERTES CLINIC & HOSPITAL',
#    '10',
#    'INF/DISP',
#    '(077)670-\n6438/09266284301',
#    'gertesclinicandhospital@yahoo.\ncom',
#    '100 VENTURA ST., BRGY. 15',
#    'SAN NICOLAS',
#    'P'],
#   ['68',
#    'GOV. ROQUE B. ABLAN, SR.\nMEMORIAL HOSPITAL',
#    '100',
#    'LEVEL 2',
#    '077-7731770/077-\n7720303',
#    'pho_grbasmh@yahoo.com',
#    'P. GOMEZ ST., BRGY. 23',
#    'LAOAG CITY',
#    'G'],
#   ['69',
#    'KARMELLI CLINIC & HOSPITAL\nPINILI, INC.',
#    '10',
#    'INF/DISP',
#    '09060075885/09178880\n508',
#    'kchpia2016@gmail.com',
#    'MANILA ROAD, BRGY. APATUT-\nLUBONG',
#    'PINILI',
#    'P'],
#   ['70',
#    'KARMELLI CLINIC AND HOSPITAL\nCORPORATION',
#    '28',
#    'LEVEL 1',
#    '077-670-\n7064/09175700343',
#    'karmelliclinic_hospital@yahoo.\ncom',
#    '# 2, LEGASPI ST., BARANGAY 29,',
#    'LAOAG CITY',
#    'P'],
#   ['71',
#    'LAOAG CITY GENERAL HOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09088835934/077-\n7728826',
#    'lcgh_lc@yahoo.com',
#    '46 BRGY. NALBO',
#    'LAOAG CITY',
#    'G'],
#   ['72',
#    'MARIANO MARCOS MEMORIAL\nHOSPITAL AND MEDICAL CENTER',
#    '200',
#    'LEVEL 3',
#    '077-6008000',
#    'mmmh_doh@yahoo.com',
#    'SAN JULIAN,',
#    'BATAC',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['73',
#    'PIDDIG DISTRICT HOSPITAL',
#    '15',
#    'INF/DISP',
#    '(077) 676-\n1406/0968845305',
#    'piddigdh@yahoo.com',
#    'AGCAOILI ST.COR.GOODBYE\nST.BRGY#2 ANAO',
#    'PIDDIG',
#    'G'],
#   ['74',
#    'RANADA GENERAL HOSPITAL',
#    '15',
#    'INF/DISP',
#    '072-6772081/072-\n7704911',
#    'ranada_gen_hospital@yahoo.co\nm',
#    'BRGY. 9 BALINTAWAK ST.,',
#    'LAOAG CITY',
#    'P'],
#   ['75',
#    'RANADA MEDICAL AND DIAGNOSTIC\nCENTER',
#    '10',
#    'INF/DISP',
#    '077-770-\n5172/09167948718',
#    'ranada_antonio@yahoo.com.ph',
#    'BRGY. 7-A, S. HERNANDO\nAVENUE,',
#    'LAOAG CITY',
#    'P'],
#   ['76',
#    'SAINT CAMILLUS DE LELLIS\nGENERAL HOSPITAL',
#    '29',
#    'INF/DISP',
#    '(077) 770-\n5507/09399367816',
#    'saintcamillushospital@yahoo.co\nm',
#    '64 ZACARIAS FLORES ST., BRGY.\n6 SAN AGUSTIN',
#    'LAOAG CITY',
#    'P'],
#   ['77',
#    'THE BLACK NAZARENE HOSPITAL,\nINC.',
#    '48',
#    'LEVEL 2',
#    '(077) 773-1757',
#    'ilocosurology@yahoo.com',
#    '29 BONOAN ST. BRGY. 2 , SAN\nBALTAZAR',
#    'SAN NICOLAS',
#    'P'],
#   ['ILOCOS SUR', None, None, None, None, None, None, None, None],
#   ['78',
#    'CANDON GENERAL HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '(077)742-6098',
#    'candongeneralhospital@gmail.c\nom',
#    'TABLAC,',
#    'CANDON',
#    'P'],
#   ['79',
#    'CANDON ST. MARTIN DE PORRES\nHOSPITAL',
#    '51',
#    'LEVEL 1',
#    '(077) 674-0513',
#    'stmartindeporreshospital@yaho\no.com',
#    '25 DE MARZO ST., SAN ANTONIO',
#    'CANDON',
#    'P'],
#   ['80',
#    'CITY OF CANDON HOSPITAL',
#    '25',
#    'LEVEL 2',
#    '(077)6044737/09175106\n039',
#    'cityofcandonhospital@yahoo.co\nm',
#    'SAN NICOLAS,',
#    'CANDON',
#    'G'],
#   ['81',
#    'CORPUZ CLINIC AND HOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09178987025/09175653\n944',
#    'corpuzclinichospital@yahoo.co\nm',
#    'MAHARLIKA HIGHWAY, BRGY.\nNAMNAMA',
#    'SINAIT',
#    'P'],
#   ['82',
#    'ILOCOS SUR COOPERATIVE MEDICAL\nMISSION GROUP & HOSPITAL',
#    '11',
#    'LEVEL 1',
#    '(077)674-\n0109/09167553268',
#    'iscmmgh_coop@yahoo.com.ph',
#    'TAMAG',
#    'VIGAN',
#    'P'],
#   ['83',
#    'ILOCOS SUR DISTRICT HOSPITAL -\nBESSANG PASS CERVANTES',
#    '25',
#    'LEVEL 1',
#    '09175200183/09096775\n560',
#    'bessangpassmemorialhospital@\nyahoo.com',
#    'NATIONAL ROAD',
#    'CERVANTES',
#    'G'],
#   ['84',
#    'ILOCOS SUR DISTRICT HOSPITAL -\nSINAIT',
#    '25',
#    'LEVEL 1',
#    '077-674-\n1059/09175681000',
#    'isdhsinait@gmail.com',
#    'CURTIN',
#    'SINAIT',
#    'G'],
#   ['85',
#    'ILOCOS SUR DISTRICT HOSPITAL-\nMAGSINGAL',
#    '25',
#    'LEVEL 1',
#    '077-604-\n0577/09175511158',
#    'hospitalmagsingaldistrictl@yah\noo.com',
#    'STA. MONICA,',
#    'MAGSINGAL',
#    'G'],
#   ['86',
#    'ILOCOS SUR DISTRICT HOSPITAL-\nNARVACAN',
#    '50',
#    'LEVEL 1',
#    '077-674-\n0271/09177122115',
#    'cisdhhospital@yahoo.com',
#    'PARATONG,',
#    'NARVACAN',
#    'G'],
#   ['87',
#    'ILOCOS SUR DISTRICT HOSPITAL-\nSALCEDO',
#    '15',
#    'INF/DISP',
#    '09063627892',
#    'salcedomedicare@yahoo.com.p\nh',
#    'POBLACION SUR',
#    'SALCEDO (BAUGEN)',
#    'G'],
#   ['88',
#    'ILOCOS SUR DISTRICT HOSPITAL-STA.\nLUCIA',
#    '25',
#    'LEVEL 1',
#    '09771455896/091779914\n41',
#    'staluciadistricthospital@yahoo.c\nom.ph',
#    'SAN JUAN',
#    'STA. LUCIA',
#    'G'],
#   ['89',
#    'ILOCOS SUR DISTRICT HOSPITAL-\nTAGUDIN',
#    '50',
#    'LEVEL 1',
#    '(077) 674-3264',
#    'tagudin_hospital@yahoo.com',
#    'BIO',
#    'TAGUDIN',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['90',
#    'ILOCOS SUR MEDICAL CENTER',
#    '75',
#    'LEVEL 1',
#    '09175680625',
#    'ilocossurmedicalcenter@gmail.c\nom',
#    'HEROES BYPASS ROAD, PARIOC\nPRIMERO',
#    'CANDON',
#    'G'],
#   ['91',
#    'ILOCOS SUR PROVINCIAL HOSPITAL\nGABRIELA SILANG',
#    '100',
#    'LEVEL 2',
#    '077-\n6741813/09399170532',
#    'pho_gabriela@yahoo.com.ph',
#    'QUIRINO BOULEVARD',
#    'VIGAN',
#    'G'],
#   ['92',
#    'JUDGE CELESTINO GUERRERO\nMEMORIAL HOSPITAL',
#    '8',
#    'INF/DISP',
#    '09262574986/09167381\n805',
#    'guerrerohospital@yahoo.com.p\nh',
#    'DAKOTA ST., POB. SUR,',
#    'STA. MARIA',
#    'P'],
#   ['93',
#    'LACASANDILE MEDICAL CLINIC AND\nDIAGNOSTIC CENTER',
#    '27',
#    'INF/DISP',
#    '09062518009',
#    'lacasandilemcdc@gmail.com',
#    'MAC ARTHUR HIGHWAY,\nLACONG',
#    'TAGUDIN',
#    'P'],
#   ['94',
#    'METRO VIGAN HOSPITAL',
#    '80',
#    'LEVEL 2',
#    '077-6740674',
#    'mvch_1998@yahoo.com.ph',
#    'ROXAS DIKE, BRGY. IV',
#    'BANTAY',
#    'P'],
#   ['95',
#    'NORTHSIDE DOCTORS HOSPITAL',
#    '100',
#    'LEVEL 2',
#    '604-0474 TO\n75/09175810911',
#    'northsidedochosp@yahoo.com.\nph',
#    'NATIONAL HIGHWAY, GUIMOD,',
#    'BANTAY',
#    'P'],
#   ['96',
#    'PIRA HOSPITAL, INC.',
#    '29',
#    'LEVEL 1',
#    '6049802/09177125823/\n09175681967',
#    'pirahospital@yahoo.com',
#    'SINGSON ST., BRGY. RIZAL',
#    'CABUGAO',
#    'P'],
#   ['97',
#    'QUIRINO PRIMARY HEALTH CARE\nFACILITY',
#    '10',
#    'INF/DISP',
#    '09108946621/09201066\n518',
#    'qphcf@yahoo.com/quirinophcf\n@gmail.com',
#    'POBLACION',
#    'QUIRINO (ANGAKI)',
#    'G'],
#   ['98',
#    'RABARA CLINIC AND HOSPITAL',
#    '10',
#    'INF/DISP',
#    '(077) 632-0123',
#    'allotrbr@yahoo.com/rabara.clin\nic@yahoo.com',
#    '59 RIZAL ST., BRGY 7',
#    'VIGAN',
#    'P'],
#   ['99',
#    'RESONABLE HOSPITAL',
#    '24',
#    'LEVEL 1',
#    '(077)742-6162',
#    'resonablehospital2002@gmail.c\nom',
#    '43 MADARANG ST., SAN JOSE,',
#    'CANDON',
#    'P'],
#   ['100',
#    'REYES ULEP CLINIC AND HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09279185217/091755473\n12',
#    'reyesulepclinicandhospital@gm\nail.com',
#    'SIMPSON STREET, POBLACION\nSUR',
#    'STA. MARIA',
#    'P'],
#   ['101',
#    'STO. CRISTO MILAGROSO HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '077-\n6741380/09175783497',
#    'stocristomilagrosohospital@gm\nail.com',
#    'NATIONAL HIGHWAY, BRGY.\nTAPAO',
#    'SINAIT',
#    'P'],
#   ['102',
#    'STO. NIÑO HOSPITAL',
#    '18',
#    'INF/DISP',
#    '077-732-5573/077-\n6041595',
#    'draumatias@yahoo.com',
#    'BALIW LAUD',
#    'STA. MARIA',
#    'P'],
#   ['103',
#    'SUERO GENERAL HOSPITAL',
#    '34',
#    'LEVEL 1',
#    '077-728-5295',
#    'suerogenhosp@yahoo.com',
#    'BACLIG',
#    'CABUGAO',
#    'P'],
#   ['104',
#    'TOLENTINO CLINIC AND HOSPITAL',
#    '10',
#    'INF/DISP',
#    '6746122/09175685960',
#    'docbenjie@yahoo.com',
#    'SAN PABLO,',
#    'STO. DOMINGO',
#    'P'],
#   ['105',
#    'UNIVERSITY OF NORTHERN\nPHILIPPINES HOSPITAL',
#    '18',
#    'INF/DISP',
#    '077-\n6797865/09175333398',
#    'unp.hospital@yahoo.com',
#    'UNIVERSITY OF NORTHERN\nPHILIPPINES, TAMAG',
#    'VIGAN',
#    'G'],
#   ['106',
#    'VQR FOUNDATION FOR MEDICAL\nAND COMMUNITY DEVELOPMENT,\nINC.',
#    '30',
#    'LEVEL 1',
#    '(077) 6742788/6322505',
#    'st.jamesvqrhospital@yahoo.com',
#    'PANTAY DAYA,',
#    'VIGAN',
#    'P'],
#   ['LA UNION', None, None, None, None, None, None, None, None],
#   ['107',
#    'AGOO FAMILY HOSPITAL',
#    '15',
#    'LEVEL 1',
#    '(072)607-\n2708/09175640199',
#    'docjoe1959@ yahoo.com',
#    'SAN PEDRO',
#    'AGOO',
#    'P']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['108',
#    'BACNOTAN DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '(072) 607-1417/6074044',
#    'bdh_bacnotan@yahoo.com',
#    'POBLACION',
#    'BACNOTAN',
#    'G'],
#   ['109',
#    'BALAOAN DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '072-\n6030280/09285555706',
#    'bldh@launion.gov.ph',
#    'BUNGOL',
#    'BALAOAN',
#    'G'],
#   ['110',
#    'BETHANY HOSPITAL, INC.',
#    '80',
#    'LEVEL 2',
#    '072-2840804/072-\n6078694',
#    'bethanyhospital_lu@yahoo.com\n.ph',
#    'WIDDOES ST.,',
#    'SAN FERNANDO CITY',
#    'P'],
#   ['111',
#    'CABA DISTRICT HOSPITAL',
#    '15',
#    'LEVEL 1',
#    '(072)607-\n0633/09171126027',
#    'cdh@launion.gov.ph',
#    'NATIONAL HIGHWAY,\nPOBLACION SUR',
#    'CABA',
#    'G'],
#   ['112',
#    'ILOCOS TRAINING AND REGIONAL\nMEDICAL CENTER',
#    '306',
#    'LEVEL 3',
#    '(072)607-6418',
#    'itrmc2010@yahoo.com/nmr.itr\nmc20@gmail.com',
#    'PARIAN,',
#    'SAN FERNANDO CITY',
#    'G'],
#   ['113',
#    'KOOP MEDICAL CLINIC',
#    '17',
#    'INF/DISP',
#    '09175142553',
#    'koopmedicalcliniclumpcc@gmai\nl.com',
#    '# 138 CONSOLACION',
#    'AGOO',
#    'P'],
#   ['114',
#    'LA UNION MEDICAL CENTER',
#    '100',
#    'LEVEL 2',
#    '(072)607-5541/072-\n6075938',
#    'launionmedicalcenter@ymail.co\nm',
#    'BRGY. NAZARENO',
#    'AGOO',
#    'G'],
#   ['115',
#    'LA UNION MEDICAL DIAGNOSTIC\nCENTER AND HOSPITAL, INC.',
#    '18',
#    'LEVEL 1',
#    '(072) 607-8339/072-\n6073898',
#    'launionmed@gmail.com',
#    'ANCHETA COR. BUCANEG STS.,\nCATBANGEN',
#    'SAN FERNANDO CITY',
#    'P'],
#   ['116',
#    'LORMA MEDICAL CENTER, INC.',
#    '200',
#    'LEVEL 3',
#    '072-700-0000 loc.\n264/09178899950',
#    'mbautista@lorma.edu/phicdept\n.lorma@gmail.com',
#    'CARLATAN,',
#    'SAN FERNANDO CITY',
#    'P'],
#   ['117',
#    'NAGUILIAN DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '(072)609-\n1018/09209459458',
#    'ndh@launion.gov.ph',
#    'NATIVIDAD',
#    'NAGUILIAN',
#    'G'],
#   ['118',
#    'ROSARIO DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '(072)687-\n0456/09154804914',
#    'rdh@launion.gov.ph',
#    'CONCEPCION,',
#    'ROSARIO',
#    'G'],
#   ['PANGASINAN', None, None, None, None, None, None, None, None],
#   ['119',
#    'ALAMINOS DOCTORS HOSPITAL, INC.',
#    '42',
#    'LEVEL 1',
#    '075-6461843',
#    'aldochos2000@gmail.com',
#    'BOLANEY',
#    'ALAMINOS',
#    'P'],
#   ['120',
#    'ASINGAN COMMUNITY HOSPITAL',
#    '24',
#    'LEVEL 1',
#    '09176256067/09985691\n425',
#    'asinhosp@yahoo.com',
#    'BYPASS ROAD, DUPAC',
#    'ASINGAN',
#    'G'],
#   ['121',
#    'BAYAMBANG DISTRICT HOSPITAL',
#    '89',
#    'LEVEL 1',
#    '(075)592-2958',
#    'bayambang_districthospital80\n@yahoo.com',
#    'BICAL NORTE,',
#    'BAYAMBANG',
#    'G'],
#   ['122',
#    'BLESSED FAMILY DOCTORS GENERAL\nHOSPITAL',
#    '75',
#    'LEVEL 2',
#    '(075) 637-\n5282/09175634077',
#    'bfdgh_2003@yahoo.com.ph',
#    'ILANG',
#    'SAN CARLOS CITY',
#    'P'],
#   ['123',
#    'BOLINAO COMMUNITY HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09688794823',
#    'bolinao_c_h@ymail.com',
#    'SAMPALOC',
#    'BOLINAO',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['124',
#    'C AND H MEDICAL AND SURGICAL\nCLINIC, INC.',
#    '8',
#    'LEVEL 1',
#    '(075)551-5409',
#    'cnhhospital@yahoo.com',
#    'SADSARAN, POBLACION',
#    'ALAMINOS',
#    'P'],
#   ['125',
#    'CONRADO F. ESTRELLA REGIONAL\nMEDICAL & TRAUMA CENTER',
#    '13',
#    'INF/DISP',
#    '09178017393',
#    'cfermtc@gmail.com',
#    'CARMAY EAST',
#    'ROSALES',
#    'G'],
#   ['126',
#    'CRISOSTOMO SAN JUAN INFIRMARY',
#    '10',
#    'INF/DISP',
#    '09567966153',
#    'tucsmel10@yahoo.com',
#    '#38 RIZAL ST. POBLACION',
#    'BANI',
#    'P'],
#   ['127',
#    'CUISON HOSPITAL INCORPORATED',
#    '18',
#    'LEVEL 1',
#    '075-515-\n5121/09175084527',
#    'cuisonhospinc@gmail.com',
#    'BURGOS ST., POBLACION OESTE',
#    'DAGUPAN CITY',
#    'P'],
#   ['128',
#    'DAGUPAN DOCTORS VILLAFLOR\nMEMORIAL HOSPITAL, INC.',
#    '100',
#    'LEVEL 2',
#    '(075) 523-2222',
#    'ddvmh_marketing@yahoo.com',
#    'MCARTHUR HIGHWAY,\nMAYOMBO DISTRICT,',
#    'DAGUPAN CITY',
#    'P'],
#   ['129',
#    'DECENA GENERAL HOSPITAL',
#    '15',
#    'LEVEL 1',
#    '09175081348',
#    'dgh_dag@yahoo.com',
#    'BONUAN GUESET,',
#    'DAGUPAN CITY',
#    'P'],
#   ['130',
#    'DEL CARMEN MEDICAL CLINIC &\nHOSPITAL, INC.',
#    '28',
#    'LEVEL 1',
#    '(075-\n6375221/09175325520',
#    'delcarmenhospital@yahoo.com',
#    'CARMEN WEST',
#    'ROSALES',
#    'P'],
#   ['131',
#    'DIVINE MERCY FOUNDATION OF\nURDANETA HOSPITAL',
#    '14',
#    'LEVEL 1',
#    '656-2103',
#    'dmhospurd@gmail.com',
#    '25 HIGH SCHOOL DRIVE, SAN\nVICENTE WEST',
#    'URDANETA',
#    'P'],
#   ['132',
#    'DR. MARCELO M. CHAN MEMORIAL\nHOSPITAL, INC.',
#    '25',
#    'LEVEL 1',
#    '(075) 632-\n1282/09228669360',
#    'dmmcmhi@yahoo.com',
#    'CARMEN WEST',
#    'ROSALES',
#    'P'],
#   ['133',
#    'EASTERN PANGASINAN DISTRICT\nHOSPITAL',
#    '150',
#    'LEVEL 2',
#    '075-572-4339',
#    'epdh_tayug@yahoo.com',
#    'NEW MAGALLANES,',
#    'TAYUG',
#    'G'],
#   ['134',
#    'EL CORAZON DE JESUS MEDICAL &\nDIAGNOSTIC CLINIC',
#    '6',
#    'INF/DISP',
#    '09062381860/075-\n6325693',
#    'elcorazondejesus12@gmail.com',
#    '54 RIZAL ST. ZONE II,\nPOBLACION',
#    'SAN QUINTIN',
#    'P'],
#   ['135',
#    'ELGUIRA GENERAL HOSPITAL',
#    '30',
#    'LEVEL 2',
#    '075-532-\n4481/09177915894',
#    'sbelguira1004@gmail.com',
#    '259 RIZAL AVE.,',
#    'SAN CARLOS CITY',
#    'P'],
#   ['136',
#    'J.V.F. CLINIC AND LYING-IN\nMEMORIAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '(075)522-3656',
#    'drjvfmh@gmail.com',
#    'ZAMORA CORNER RIVERA STS./\nBRGY. IV',
#    'DAGUPAN CITY',
#    'P'],
#   ['137',
#    "JESUS' HEALING HANDS INFIRMARY,\nINC.",
#    '12',
#    'INF/DISP',
#    '6326085/09189455027',
#    'jhhhospital@yahoo.com',
#    '88 RIZAL ST., POBLACION',
#    'URBIZTONDO',
#    'P'],
#   ['138',
#    'JESUS NAZARENE GENERAL\nHOSPITAL',
#    '30',
#    'LEVEL 2',
#    '075-542-5758',
#    'jngh08@yahoo.com',
#    'VICENTE SOLIS ST., POBLACION',
#    'LINGAYEN',
#    'P'],
#   ['139',
#    'LINGAYEN DISTRICT HOSPITAL',
#    '40',
#    'LEVEL 1',
#    '075-542-2295',
#    'ldh_pang@yahoo.com',
#    'POBLACION',
#    'LINGAYEN',
#    'G'],
#   ['140',
#    'LOPEZ FAMILY CLINIC AND HOSPITAL',
#    '12',
#    'INF/DISP',
#    '(075)632-1023',
#    'ftlopez_md0410@yahoo.com',
#    '10 GEN. LUNA ST. COR. JOCSON\nST.,',
#    'MANGATAREM',
#    'P'],
#   ['141',
#    'LUZON MEDICAL CENTER, INC',
#    '70',
#    'LEVEL 2',
#    '(075)529-\n1954/09266518973',
#    'luzonmedical@gmail.com',
#    '329 MCARTHUR HIGHWAY\nTAPUAC DISTRICT',
#    'DAGUPAN CITY',
#    'P'],
#   ['142',
#    'MANAOAG COMMUNITY HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '(075)519-4833',
#    'manaoagcommunityhospital201\n3@yahoo.com.ph',
#    'BARITAO',
#    'MANAOAG',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['143',
#    'MANGATAREM DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09451901075',
#    'mangataremdistricthospital@g\nmail.com',
#    'CASILAGAN,',
#    'MANGATAREM',
#    'G'],
#   ['144',
#    'MAPANDAN COMMUNITY HOSPITAL',
#    '20',
#    'LEVEL 1',
#    '075-632-0491',
#    'mapandancommhosp@yahoo.c\nom',
#    '024 FIRE TREE ST., POBLACION',
#    'MAPANDAN',
#    'G'],
#   ['145',
#    'MBP-BLESSED TRINITY GENERAL\nHOSPITAL, INC.',
#    '18',
#    'LEVEL 1',
#    '632-1288/09209687680',
#    'mbp_btgh_inc@yahoo.com.ph',
#    'UMANGAN',
#    'MANGATAREM',
#    'P'],
#   ['146',
#    'MEDICAL CENTRUM DAGUPAN',
#    '42',
#    'LEVEL 2',
#    '075-6374890',
#    'medcentrum_dagupan@yahoo.\ncom.ph',
#    'AB FERNANDEZ EAST AVENUE\nEAST',
#    'DAGUPAN CITY',
#    'P'],
#   ['147',
#    'NAZARETH GENERAL HOSPITAL, INC.',
#    '60',
#    'LEVEL 2',
#    '075-5221110/5221071',
#    'ngh1959@yahoo.com',
#    '203 POGO CHICO PEREZ\nBOULEVARD',
#    'DAGUPAN CITY',
#    'P'],
#   ['148',
#    'NORTHERN LUZON ADVENTIST\nHOSPITAL, INC.',
#    '18',
#    'LEVEL 1',
#    '075-\n6323200/09155535214',
#    'nlahospital@gmail.com',
#    'MCARTHUR HIWAY, ARTACHO',
#    'SISON',
#    'P'],
#   ['149',
#    'NUESTRO SEÑOR SANTO NIÑO\nHOSPITAL, INC.',
#    '12',
#    'LEVEL 1',
#    '075-\n6335805/09289393242',
#    'nssnh@yahoo.com.ph',
#    'JUAN LUNA ST., POBLACION SUR',
#    'BAYAMBANG',
#    'P'],
#   ['150',
#    'ORDOÑEZ MEDICAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '075-6321965',
#    'shirleyasinas@yahoo.com',
#    'ZONE V, POBLACION',
#    'VILLASIS',
#    'P'],
#   ['151',
#    'PANGASINAN DOCTORS HOSPITAL',
#    '37',
#    'LEVEL 2',
#    '(075) 632-5870',
#    'recordspdh@gmail.com',
#    '307 RIZAL AVENUE,',
#    'SAN CARLOS CITY',
#    'P'],
#   ['152',
#    'PANGASINAN PROVINCIAL HOSPITAL',
#    '250',
#    'LEVEL 2',
#    '075-531-\n3263/09468126975',
#    'pphscgh@yahoo.com',
#    'BARANGAY BOLINGIT',
#    'SAN CARLOS CITY',
#    'G'],
#   ['153',
#    'POZORRUBIO COMMUNITY HOSPITAL',
#    '44',
#    'LEVEL 1',
#    '09338546496/09189044\n024',
#    'pozmunhospital@gmail.com',
#    'TALOGTOG,',
#    'POZORUBIO',
#    'G'],
#   ['154',
#    'PRO-CARE MEDICAL CLINIC AND\nINFIRMARY',
#    '7',
#    'INF/DISP',
#    '09178205888/09060218\n963',
#    'pcmch2015@gmail.com',
#    'NATIONAL ROAD, PUGARO',
#    'BALUNGAO',
#    'P'],
#   ['155',
#    'REGION I MEDICAL CENTER',
#    '300',
#    'LEVEL 3',
#    '075-515-8901',
#    'region1mc@gmail.com',
#    'ARELLANO ST.,',
#    'DAGUPAN CITY',
#    'G'],
#   ['156',
#    'RILLERA MEDICAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09175503562/09189376\n914',
#    'rmhbolinao@yahoo.com',
#    'AROSAN GERMINAL',
#    'BOLINAO',
#    'P'],
#   ['157',
#    'ROSALES CHUA PUN MEMORIAL\nHOSPITAL INC.',
#    '12',
#    'LEVEL 1',
#    '09998820850/09178779\n712',
#    'rchuapun.hosp@gmail.com.ph',
#    'PUROK 05, CARMAY EAST',
#    'ROSALES',
#    'P'],
#   ['158',
#    'ROSALES INFIRMARY UNIT',
#    '12',
#    'INF/DISP',
#    '(075) 517-\n6065/09687040043',
#    'rosalesinfirmaryunit@gmail.co\nm',
#    'PINE ST., POBLACION ZONE V',
#    'ROSALES',
#    'G'],
#   ['159',
#    'SPECIALIST GROUP HOSPITAL AND\nTRAUMA CENTER',
#    '80',
#    'LEVEL 2',
#    '075-522-2254',
#    'carl_md2000@yahoo.com',
#    'TAPUAC DISTRICT',
#    'DAGUPAN CITY',
#    'P'],
#   ['160',
#    'ST. CAMILLUS MATERNITY &\nPOLYCLINIC FOUNDATION INC.',
#    '14',
#    'INF/DISP',
#    '529-1909/099915378570',
#    'st.camillusmanaoag@gmail.com',
#    'BRGY. LICSI',
#    'MANAOAG',
#    'P']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['161',
#    'STO. NIÑO DE CASIPIT INFIRMARY',
#    '15',
#    'INF/DISP',
#    '529-2295',
#    'stoninodecasipit81@gmail.com',
#    'AVENIDA RIZAL WEST,\nPOBLACION',
#    'LINGAYEN',
#    'P'],
#   ['162',
#    'SUAL PRIMARY CARE FACILITY -\nINFIRMARY',
#    '6',
#    'INF/DISP',
#    '09753068283/09190646\n207',
#    'pcfinfirmary@gmail.com',
#    'CAOAYAN',
#    'SUAL',
#    'G'],
#   ['163',
#    'TAYUG FAMILY HOSPITAL',
#    '70',
#    'LEVEL 2',
#    '(075)6342845/0908-\n8934123',
#    'tayugfamilyhospital@yahoo.co\nm',
#    'BARANGOBONG',
#    'TAYUG',
#    'P'],
#   ['164',
#    'THE MEDICAL CITY PANGASINAN',
#    '75',
#    'LEVEL 2',
#    '075-615-2273 loc\n405/09155332798',
#    'tmcpangasinan@themedicalcity\n.com',
#    'NABLE ST., PANTAL DISTRICT',
#    'DAGUPAN CITY',
#    'P'],
#   ['165',
#    'UMINGAN COMMUNITY HOSPITAL',
#    '15',
#    'LEVEL 1',
#    '576-5033/0915687800',
#    'uminganch@yahoo.com',
#    'BURGOS ST., POBLACION WEST',
#    'UMINGAN',
#    'G'],
#   ['166',
#    'UNIVERSAL HEALTH GENERAL\nHOSPITAL',
#    '50',
#    'LEVEL 2',
#    '075-\n6323907/09177915894',
#    'uhgh143@gmail.com',
#    'CABATLING',
#    'MALASIQUI',
#    'P'],
#   ['167',
#    'URDANETA DISTRICT HOSPITAL',
#    '110',
#    'LEVEL 1',
#    '09171358776/097780647\n25',
#    'urdanetadistricthospital@gmail.\ncom',
#    'DILAN - PAURIDO',
#    'URDANETA',
#    'G'],
#   ['168',
#    'URDANETA SACRED HEART\nHOSPITAL',
#    '128',
#    'LEVEL 2',
#    '075-656-2296',
#    'ushhi1@yahoo.com',
#    'MC ARTHUR HI-WAY, SAN\nVICENTE,',
#    'URDANETA',
#    'P'],
#   ['169',
#    'VELASQUEZ MEDICAL CLINIC AND\nHOSPITAL',
#    '11',
#    'INF/DISP',
#    '(075) 632-3316',
#    'mackay_maricel@yahoo.com',
#    '3 MABINI ST.,',
#    'MANGATAREM',
#    'P'],
#   ['170',
#    'VIRGEN MILAGROSA MEDICAL\nCENTER',
#    '75',
#    'LEVEL 2',
#    '6324093/2030000/6324\n094',
#    'vmmcphilhealth@gmail.com',
#    'MARTIN P. POSADAS AVE.,',
#    'SAN CARLOS CITY',
#    'P'],
#   ['171',
#    'WESTERN PANGASINAN DISTRICT\nHOSPITAL',
#    '75',
#    'LEVEL 1',
#    '075-632-3810',
#    'wpdhalaminosnew@yahoo.com',
#    'SAN JOSE DRIVE PUROK SABARO\nPOBLACION',
#    'ALAMINOS',
#    'G'],
#   ['REGION II', None, None, None, None, '', None, None, None],
#   ['BATANES', None, None, None, None, None, None, None, None],
#   ['172',
#    'BATANES GENERAL HOSPITAL',
#    '75',
#    'LEVEL 1',
#    '09190996724',
#    'bataneshospital@gmail.com',
#    'NATIONAL ROAD, BARANGAY\nKAYHUVOKAN,',
#    'BASCO',
#    'G'],
#   ['173',
#    'ITBAYAT DISTRICT HOSPITAL',
#    '15',
#    'INF/DISP',
#    '09089148078',
#    'idh.batanes@gmail.com',
#    'NATIONAL ROAD SAN RAFAEL,',
#    'ITBAYAT',
#    'G'],
#   ['CAGAYAN', None, None, None, None, None, None, None, None],
#   ['174',
#    'ALCALA MUNICIPAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09177758988',
#    'alcalamunicipalhospital@gmail.\ncom',
#    'CENTRO NORTE,',
#    'ALCALA',
#    'G'],
#   ['175',
#    'ALFONSO PONCE ENRILE MEMORIAL\nDISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09052011942',
#    'apemdhospital@gmail.com',
#    'MABINI ST',
#    'GONZAGA',
#    'G'],
#   ['176',
#    'APARRI PROVINCIAL HOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09175728105/093637184\n30',
#    'adh.ph@yahoo.com',
#    'NATIONAL HIGHWAY, TORAN,',
#    'APARRI',
#    'G'],
#   ['177',
#    'APAYAO CAGAYAN MEDICAL CENTER\nINC.',
#    '25',
#    'LEVEL 1',
#    '09171466558',
#    'apayaocagayanmedcenter@gma\nil.com',
#    'NO. 07 NATIONAL HIGHWAY,\nLIBERTAD,',
#    'ABULUG',
#    'P'],
#   ['178',
#    'BAGGAO DISTRICT HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09177755087',
#    'bdhtungel@gmail.com',
#    'TUNGEL,',
#    'BAGGAO',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['179',
#    'BALLESTEROS DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09452462675',
#    'ballesterosdistricthospital@gma\nil.com',
#    'MABINI ST., CABULUAN WEST,',
#    'BALLESTEROS',
#    'G'],
#   ['180',
#    'CAGAYAN UNITED DOCTORS\nMEDICAL CENTER OF TUGUEGARAO\nCITY, INC.',
#    '100',
#    'LEVEL 2',
#    '09178664031/091715552\n44',
#    'cudmc.philhealth@gmail.com',
#    'NO. 7 BAGAY ROAD, CARITAN\nCENTRO',
#    'TUGUEGARAO CITY',
#    'P'],
#   ['181',
#    'CAGAYAN VALLEY MEDICAL CENTER',
#    '500',
#    'LEVEL 3',
#    '(078) 302-0000',
#    'cvmcr2@gmail.com',
#    'MAHARLIKA HIGHWAY, CARIG\nSUR,',
#    'TUGUEGARAO CITY',
#    'G'],
#   ['182',
#    'CHARLES W. SELBY MEMORIAL\nHOSPITAL, INC.',
#    '25',
#    'LEVEL 1',
#    '(078) 888-\n2485/09778043530',
#    'cwsmhi@gmail.com/andayaelle\nn22@yahoo.com',
#    'DIEGO SILANG STREET, PUNTA,',
#    'APARRI',
#    'P'],
#   ['183',
#    'DIVINE MERCY WELLNESS CENTER,\nINC.',
#    '100',
#    'LEVEL 2',
#    '09178722461 /\n09175783647',
#    'a.dmwc@yahoo.com',
#    'ARELLANO COR. BURGOS STS.,\nBRGY. CENTRO 06,',
#    'TUGUEGARAO CITY',
#    'P'],
#   ['184',
#    'DR. DOMINGO S. DE LEON GENERAL\nHOSPITAL',
#    '14',
#    'LEVEL 1',
#    '(078) 304-0574/844-\n0013',
#    'clinica.deleon@hotmail.com',
#    '141- A BONIFACIO STREET,\nCENTRO 1,',
#    'TUGUEGARAO CITY',
#    'P'],
#   ['185',
#    'DR. RONALD P. GUZMAN MEDICAL\nCENTER, INC.',
#    '100',
#    'LEVEL 2',
#    '(078) 304-0925/0926',
#    'ao_rpgmc@yahoo.com/phic_rp\ngmc@yahoo.com',
#    'ENRILE AVENUE, CARIG,',
#    'TUGUEGARAO CITY',
#    'P'],
#   ['186',
#    'DR. TOMAS L. NOLASCO SR.\nMEMORIAL HOSPITAL-\nREPRODUCTIVE HEALTH CENTER',
#    '10',
#    'INF/DISP',
#    '09275149145/09178300\n841',
#    'dtnh_rhc@yahoo.com',
#    'CENTRO SUR,',
#    'GATTARAN',
#    'G'],
#   ['187',
#    'FR. GERRY FILIPPETTO MEMORIAL\nFOUNDATION HOSPITAL, INC.',
#    '17',
#    'LEVEL 1',
#    '09359038679/09635974\n964',
#    'fgfmfh@yahoo.com',
#    'STA. CRUZ,',
#    'STA. ANA',
#    'P'],
#   ['188',
#    'GATTARAN EMERGENCY HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09175332910',
#    'gattaranemergencyhospital@ya\nhoo.com',
#    'CALAOAGAN DACKEL,',
#    'GATTARAN',
#    'G'],
#   ['189',
#    'GRUPO MEDICO DE DIOS INC.',
#    '33',
#    'LEVEL 2',
#    '09175825518/091757863\n33',
#    'grupomedicodedios.ph@gmail.c\nom',
#    'BULALA,',
#    'CAMALANIUGAN',
#    'P'],
#   ['190',
#    'HOLY INFANT HOSPITAL OF\nTUGUEGARAO INC.',
#    '15',
#    'LEVEL 1',
#    '09175184828',
#    'holyinfanthospital@yahoo.com',
#    '54 WASHINGTON STREET,\nCENTRO 04,',
#    'TUGUEGARAO CITY',
#    'P'],
#   ['191',
#    'LASAM DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09177758988',
#    'lasamdistricthospital@yahoo.co\nm',
#    'IGNACIO B. JURADO,',
#    'LASAM',
#    'G'],
#   ['192',
#    'LYCEUM OF APARRI HOSPITAL',
#    '36',
#    'LEVEL 1',
#    '(078) 377-\n3830/09171595151',
#    'lah.hospital@yahoo.com',
#    'MACANAYA,',
#    'APARRI',
#    'P'],
#   ['193',
#    'MATILDE A. OLIVAS DISTRICT\nHOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09175878708',
#    'matildeaolivas@yahoo.com',
#    'GEN. BATALLA,',
#    'CAMALANIUGAN',
#    'G'],
#   ['194',
#    'NORTHERN CAGAYAN DISTRICT\nHOSPITAL',
#    '17',
#    'INF/DISP',
#    '09064884728/0906488\n4728',
#    'ncdh2015ssanchezmira@gmail.\ncom',
#    'SAN ANDRES,',
#    'SANCHEZ-MIRA',
#    'G'],
#   ['195',
#    'NUESTRA SEÑORA DE PIAT DISTRICT\nHOSPITAL',
#    '40',
#    'LEVEL 1',
#    '09353569295/091715923\n31',
#    'nspdh01@yahoo.com',
#    'MAGUILLING,',
#    'PIAT',
#    'G'],
#   ['196',
#    'RAPHAEL GENERAL HOSPITAL',
#    '70',
#    'LEVEL 2',
#    '09569457834',
#    'raphaelgeneralhospital@gmail.c\nom',
#    '# 4 BAGAY ROAD, ATULAYAN\nSUR',
#    'TUGUEGARAO CITY',
#    'P']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['197',
#    'ST. PAUL HOSPITAL OF TUGUEGARAO,\nINC.',
#    '150',
#    'LEVEL 2',
#    '(078) 844-8191 TO\n93/09778397905',
#    'sph_tuguegarao@yahoo.com.ph',
#    'LUNA EXTENSION, UGAC NORTE,',
#    'TUGUEGARAO CITY',
#    'P'],
#   ['198',
#    'STA. ANA COMMUNITY HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09177658437',
#    'sachospital@yahoo.com',
#    'PINES DRIVE, CENTRO,',
#    'STA. ANA',
#    'G'],
#   ['199',
#    'TUAO DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09173125706',
#    'tdh_pgoc@yahoo.com',
#    'PUROK 04, BULAGAO,',
#    'TUAO',
#    'G'],
#   ['200',
#    "TUGUEGARAO CITY PEOPLE'S\nGENERAL HOSPITAL",
#    '68',
#    'LEVEL 1',
#    '844-1337/09175781986',
#    'tuguegaraocityPGH@yahoo.com',
#    'LUNA STREET, CENTRO 6,',
#    'TUGUEGARAO CITY',
#    'G'],
#   ['ISABELA', None, None, None, None, None, None, None, None],
#   ['201',
#    'A.M. YUMENA GENERAL HOSPITAL\nINC.',
#    '14',
#    'LEVEL 1',
#    '09178849693/ /078-642-\n0171',
#    'a.m.yumenageneralhospitalinc.\n@gmail.com/\ntyumena@yahoo.com',
#    'DOÑA SYQUIA SREET., BANTUG,',
#    'ROXAS',
#    'P'],
#   ['202',
#    'ADVENTIST HOSPITAL-SANTIAGO\nCITY, INC.',
#    '50',
#    'LEVEL 2',
#    '09154293223/\n09171168512',
#    'adminsec@adventisthealth.stg.c\nom',
#    'PUROK-5, NATIONAL HIGHWAY,\nMABINI',
#    'SANTIAGO CITY',
#    'P'],
#   ['203',
#    'ANGADANAN INTEGRATED\nCOMMUNITY HOSPITAL',
#    '12',
#    'INF/DISP',
#    '09157688511/091757416\n93',
#    'Aichospital@gmail.com',
#    'CENTRO 3,',
#    'ANGADANAN',
#    'G'],
#   ['204',
#    'BBCSS PEDIATRIC, MEDICAL AND\nSURGICAL CLINIC',
#    '12',
#    'INF/DISP',
#    '09175741414/091790790\n27',
#    'doksevilleja@yahoo.com',
#    'QUEZON STREET, BARANGAY 02',
#    'SAN MATEO',
#    'P'],
#   ['205',
#    'CABATUAN FAMILY HOSPITAL, INC.',
#    '20',
#    'LEVEL 1',
#    '09175915850/(078) 652-\n0783',
#    'cabatuan.cf1978ch@gmail.com',
#    'CENTRO',
#    'CABATUAN',
#    'P'],
#   ['206',
#    'CALLANG GENERAL HOSPITAL AND\nMEDICAL CENTER, INC.',
#    '55',
#    'LEVEL 2',
#    '09175199775',
#    'callang_hospital@yahoo.com',
#    'JUDGE TAGUINOD ST., CENTRO\nEAST,',
#    'SANTIAGO CITY',
#    'P'],
#   ['207',
#    'CAMP MELCHOR F. DELA CRUZ\nSTATION HOSPITAL',
#    '30',
#    'INF/DISP',
#    '09568661299',
#    'cmfdcsh5@yahoo.com',
#    'UPI,',
#    'GAMU',
#    'G'],
#   ['208',
#    'CAUAYAN DISTRICT HOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09175102100',
#    'cdh_isabela@yahoo.com',
#    'ROSEMARIE REYES ST.,DISTRICT\n01',
#    'CAUAYAN',
#    'G'],
#   ['209',
#    'CAUAYAN FAMILY HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09328645759/078-\n6532411',
#    'marlene_aquino321@yahoo.co\nm',
#    'ROSEMARIE REYES STREET,\nPRENZA, DISTRICT 1',
#    'CAUAYAN',
#    'P'],
#   ['210',
#    'CAUAYAN MEDICAL SPECIALISTS\nHOSPITAL',
#    '95',
#    'LEVEL 1',
#    '09175742629',
#    'cmshinc_1401@yahoo.com',
#    '27 BURGOS ST., DISTRICT II',
#    'CAUAYAN',
#    'P'],
#   ['211',
#    'CITY OF ILAGAN MEDICAL CENTER',
#    '71',
#    'LEVEL 1',
#    '09164736184',
#    'herbeebarrios@yahoo.com',
#    'BRGY. LULLUTAN, CITY OF\nILAGAN, ISABELA',
#    'ILAGAN',
#    'G'],
#   ['212',
#    'DAYOS-PASCUAL MEDICAL CLINIC',
#    '17',
#    'LEVEL 1',
#    '09175025795/091715033\n73',
#    'dpmcroxas@gmail.com',
#    'RANG-AYAN',
#    'ROXAS',
#    'P'],
#   ['213',
#    'DE VERA MEDICAL CENTER, INC.',
#    '50',
#    'LEVEL 2',
#    '096715567455',
#    'dvmc20@yahoo.com/bona_dvg\nh@yahoo.com',
#    'CITY ROAD, CALAO EAST,',
#    'SANTIAGO CITY',
#    'P'],
#   ['214',
#    'DELFIN ALBANO MEMORIAL\nHOSPITAL',
#    '10',
#    'INF/DISP',
#    '09171424236',
#    'damh_da@yahoo.com',
#    'RAGAN SUR',
#    'MAGSAYSAY (DELFIN\nALBANO)',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['215',
#    "DEMANO'S MEDICAL AND PEDIATRIC\nCLINIC",
#    '8',
#    'INF/DISP',
#    '09268803713/09434564\n821',
#    'demanoclinicramon@yahoo.co\nm.ph/joycedemano@yahoo.com',
#    '# 11 BONIFACIO ST., BUGALLON\nPROPER',
#    'RAMON',
#    'P'],
#   ['216',
#    'DR. ESTER R. GARCIA MEDICAL\nCENTER, INC.',
#    '35',
#    'LEVEL 1',
#    '09664968073/09352714\n530',
#    'ergmc_hospital@hotmail.com',
#    'FNDY BLVD., SAN FERMIN',
#    'CAUAYAN',
#    'P'],
#   ['217',
#    'DR. VICTOR S. VILLAROMAN\nMEMORIAL HOSPITAL',
#    '17',
#    'LEVEL 1',
#    '09171008061',
#    'vsvmdh2005@gmail.com',
#    '24 BURGOS ST., CENTRO\nPOBLACION',
#    'ILAGAN',
#    'P'],
#   ['218',
#    'DUMLAO HOSPITAL',
#    '15',
#    'LEVEL 1',
#    '09178256200/078-642-\n0003',
#    'hospital_dumlao@yahoo.com',
#    '28 S. OSMEÑA ST., VIRA',
#    'ROXAS',
#    'P'],
#   ['219',
#    'ECHAGUE DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09171789163 / 078-\n3059088',
#    'echague_districthospital@yaho\no.com',
#    'IPIL',
#    'ECHAGUE',
#    'G'],
#   ['220',
#    'ELVIN U. MASIGAN INTEGRATED\nMEMORIAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09175771316',
#    'eumimh18@gmail.com',
#    'BLISS SITE, POBLACION 1,',
#    'STA. MARIA',
#    'G'],
#   ['221',
#    'FLORES MEMORIAL MEDICAL\nCENTER',
#    '29',
#    'LEVEL 1',
#    '09175745016/091783394\n14',
#    'a.aofmh@yahoo.com',
#    '16 ABAUAG ST., VILLASIS',
#    'SANTIAGO CITY',
#    'P'],
#   ['222',
#    'GAMBALAN HOSPITAL',
#    '15',
#    'INF/DISP',
#    '09178881835',
#    'gambalan.hospital@yahoo.com',
#    'ZONE 06., SAN ANTONIO,',
#    'MAGSAYSAY (DELFIN\nALBANO)',
#    'P'],
#   ['223',
#    "GOD'S WILL MEDICAL HOSPITAL",
#    '12',
#    'LEVEL 1',
#    '09209520869',
#    'gwmhospitalhrd@yahoo.com',
#    '#90 ROXAS ST.,DISTRICT 02',
#    'CAUAYAN',
#    'P'],
#   ['224',
#    'GOVERNOR FAUSTINO N. DY SR.\nMEMORIAL HOSPITAL',
#    '100',
#    'LEVEL 1',
#    '(078 ) 624-1688 /\n09178901320',
#    'gfndsmh@yahoo.com.ph',
#    'MAHARLIKA ROAD, CALAMAGUI\n2ND,',
#    'ILAGAN',
#    'G'],
#   ['225',
#    'ISABELA DOCTORS GENERAL\nHOSPITAL INC.',
#    '50',
#    'LEVEL 1',
#    '09186564665 /\n09274106105',
#    'idghinc@gmail.com /\ncarlo_md99@yahoo.com',
#    'NATIONAL HIGHWAY,\nBALIGATAN',
#    'ILAGAN',
#    'P'],
#   ['226',
#    'ISABELA SOUTH SPECIALISTS\nHOSPITAL INC.',
#    '58',
#    'LEVEL 1',
#    '09175386415 / 078-\n3053447',
#    'isshi2015@gmail.com',
#    'NATIONAL HIGHWAY, IPIL',
#    'ECHAGUE',
#    'P'],
#   ['227',
#    'ISABELA UNITED DOCTORS MEDICAL\nCENTER, INC.',
#    '113',
#    'LEVEL 2',
#    '09175761255',
#    'iudmc@yahoo.com.ph',
#    'NATIONAL HIGHWAY,\nBARANGAY CABARUAN,',
#    'CAUAYAN',
#    'P'],
#   ['228',
#    'JAVONILLO HOSPITAL, INC.',
#    '17',
#    'LEVEL 1',
#    '09276942054; 078-\n6820112',
#    'javonillohospital2015@gmail.co\nm',
#    'MAGSAYSAY,',
#    'CORDON',
#    'P'],
#   ['229',
#    'JUVELO FAMILY CLINIC',
#    '10',
#    'INF/DISP',
#    '09158664933/09163774\n549',
#    'venicejulian@yahoo.com',
#    'NATIONAL HIGHWAY, BRGY. 3',
#    'SAN MATEO',
#    'P'],
#   ['230',
#    'LUCAS-PAGUILA MEDICAL HOSPITAL\nINCORPORATED',
#    '39',
#    'LEVEL 1',
#    '09163811021',
#    'lpmhi100@gmail.com',
#    '100 RIZAL ST., MAGSAYSAY,',
#    'ALICIA',
#    'P'],
#   ['231',
#    'MANANGO HOSPITAL',
#    '19',
#    'LEVEL 1',
#    '09773812331/09278888\n322',
#    'manango_hospital@yahoo.com;\nrecords.manango@gmail.com',
#    'NATIONAL HIGHWAY, SAN\nANTONIO',
#    'ALICIA',
#    'P'],
#   ['232',
#    'MANUEL A. ROXAS DISTRICT\nHOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09054641966 /\n09190955611',
#    'mardh_rxs@yahoo.com.ph',
#    'SAN ANTONIO',
#    'ROXAS',
#    'G'],
#   ['233',
#    'MILAGROS ALBANO DISTRICT\nHOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09053476576',
#    'madh_cabagan@yahoo.com',
#    'NGARAG,',
#    'CABAGAN',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['234',
#    'PADRON-TIBIO MEDICAL CLINIC',
#    '16',
#    'LEVEL 1',
#    '09175346539',
#    'padrontibio.medc@yahoo.com.p\nh',
#    'PASUQUIN, SAN JOSE',
#    'AURORA',
#    'P'],
#   ['235',
#    'PALANAN STATION HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09678363252/09368081\n460',
#    'psh_palisa@gmail.com',
#    'DICABISAGAN WEST,',
#    'PALANAN',
#    'G'],
#   ['236',
#    'PIEDAD MEDICAL CLINIC',
#    '10',
#    'INF/DISP',
#    '(078)3230880',
#    'piedadmedicalclinic@yahoo.co\nm',
#    '32 RIZAL ST., BRGY. 4',
#    'SAN MATEO',
#    'P'],
#   ['237',
#    'PROSPERO G. BELLO INTEGRATED\nCOMMUNITY HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09777059698/09153114\n033',
#    'pgbich_jones@yahoo.com',
#    'BARANGAY 1,',
#    'JONES',
#    'G'],
#   ['238',
#    'PROVIDERS MULTI-PURPOSE\nCOOPERATIVE MEDICAL CENTER',
#    '35',
#    'LEVEL 1',
#    '09176250992/09065154\n352',
#    'pmpcmedicalcenter@gmail.com',
#    '1AH26, SAN MANUEL,',
#    'NAGUILIAN',
#    'P'],
#   ['239',
#    'QUE MEDICAL CLINIC, LYING IN AND\nPHARMACY',
#    '15',
#    'INF/DISP',
#    '09177747674, (078) 323-\n03-09',
#    'quemedicalclinic@yahoo.com',
#    '17 LAMAN ST., BARANGAY\nDISTRICT 2,',
#    'TUMAUINI',
#    'P'],
#   ['240',
#    'QUEZON COMMUNITY HOSPITAL',
#    '15',
#    'INF/DISP',
#    '09172450034/091775153\n05',
#    'qch_1994@yahoo.com',
#    'ARELLANO',
#    'QUEZON',
#    'G'],
#   ['241',
#    "RENMAR SPECIALISTS' HOSPITAL",
#    '10',
#    'LEVEL 1',
#    '078-305-\n2743,09209019937',
#    'marichuelefante@yahoo.com',
#    'MAHARLIKA HIGHWAY CORNER\nPATUL ROAD, PLARIDEL',
#    'SANTIAGO CITY',
#    'P'],
#   ['242',
#    'SAN ANTONIO CITY OF ILAGAN\nHOSPITAL',
#    '10',
#    'INF/DISP',
#    '09052132976',
#    'ajpaguirigan@yahoo.com/jcpag\nuirigan@gmail.com',
#    'P 7, CENTRO, SAN ANTONIO,',
#    'ILAGAN',
#    'G'],
#   ['243',
#    'SAN MARIANO COMMUNITY\nHOSPITAL',
#    '10',
#    'LEVEL 1',
#    '09186555500',
#    'sanmariano_communityhospita\nl@yahoo.com',
#    'PURO5, SANTA FILOMENA',
#    'SAN MARIANO',
#    'G'],
#   ['244',
#    'SAN MATEO INTEGRATED\nCOMMUNITY HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09175032406',
#    'smich0215@gmail.com',
#    'ROXAS ST., CORNER AGLIPAY\nSTREET, BARANGAY 4',
#    'SAN MATEO',
#    'G'],
#   ['245',
#    'SAN MATEO MULTICARE HOSPITAL\nINC.',
#    '20',
#    'LEVEL 1',
#    '09666918883/078 323\n2543',
#    'sanmateomulticare@gmail.com',
#    'QUIRINO STREET, BARANGAY 1',
#    'SAN MATEO',
#    'P'],
#   ['246',
#    'SANTIAGO MEDICAL CITY',
#    '109',
#    'LEVEL 2',
#    '09175747561',
#    'santiagomedicalcity@yahoo.co\nm',
#    'PUROK 7, NATIONAL HIGHWAY,\nRIZAL',
#    'SANTIAGO CITY',
#    'P'],
#   ['247',
#    'SOLLER GENERAL HOSPITAL, INC.',
#    '17',
#    'LEVEL 1',
# ...
#    'INF/DISP',
#    '09306209702',
#    'lapazmunicipalhospital@gmail.\ncom',
#    'PUROK 4, POBLACION,',
#    'LA PAZ',
#    'G'],
#   ['1766',
#    'LORETO MUNICIPAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09051134448 (HOF)',
#    'maria.alma.bernardo.pgas@gm\nail.com',
#    'CASAL ST., POBLACION,',
#    'LORETO',
#    'G'],
#   ['1767',
#    'PHILSAGA MINING HOSPITAL',
#    '14',
#    'INF/DISP',
#    '085\n2350045/09985502579/\n09308022616',
#    'admin_agusan@philsaga.com',
#    'CONSUELO,',
#    'BUNAWAN',
#    'P'],
#   ['1768',
#    'TALACOGON DISTRICT HOSPITAL',
#    '30',
#    'LEVEL 1',
#    '09393638951',
#    'tdh_talacogonADS@yahoo.com',
#    'PUROK BAYABAS, SAN ISIDRO,',
#    'TALACOGON',
#    'G'],
#   ['1769',
#    'VALENTINA GALIDO PLAZA\nMEMORIAL HOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09300451551',
#    'vgpmh.official@gmail.com',
#    'PUROK 2, SAN TEODORO,',
#    'BUNAWAN',
#    'G'],
#   ['SURIGAO DEL NORTE', None, None, None, None, None, None, None, None],
#   ['1770',
#    'ALBOR DISTRICT HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09478344383/\n09208227285 (HOF)',
#    'albordistrict.hospital@gmail.co\nm',
#    'LLAMERA STREET, NATIONAL\nHIGHWAY, SAN ANTONIO,',
#    'LIBJO (ALBOR)',
#    'G'],
#   ['1771',
#    'CARAGA REGIONAL HOSPITAL',
#    '150',
#    'LEVEL 2',
#    '086 8262459',
#    'caragahospital@gmail.com',
#    'RIZAL ST., BRGY. WASHINGTON,',
#    'SURIGAO CITY',
#    'G'],
#   ['1772',
#    'DINAGAT DISTRICT HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09100154388',
#    'ddhpdi2018@gmail.com',
#    'BRGY. ESCOLTA,',
#    'DINAGAT',
#    'G'],
#   ['1773',
#    'LORETO DISTRICT HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09101052469',
#    'loretodistricthospital.pdi@gmail\n.com',
#    'NATIONAL HIGHWAY, CARMEN,',
#    'LORETO',
#    'G'],
#   ['1774',
#    'MAINIT MEDICARE COMMUNITY\nHOSPITAL',
#    '10',
#    'INF/DISP',
#    '09518499475/09399231\n856 (HOF)',
#    'mainitmedicarehospital@yahoo.\ncom.sg',
#    'MUPAS ST., BRGY. MAGSAYSAY,',
#    'MAINIT',
#    'G'],
#   ['1775',
#    'MALIMONO DISTRICT HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09517995442',
#    'malimonodh@gmail.com',
#    'BRGY. BINOCARAN,',
#    'MALIMONO',
#    'G'],
#   ['1776',
#    'MIRANDA FAMILY HOSPITAL',
#    '35',
#    'LEVEL 1',
#    '086\n8261057/09102405925',
#    'mirfamhospital@yahoo.com',
#    'KM. 1, NATIONAL HIGHWAY,\nBRGY. WASHINGTON,',
#    'SURIGAO CITY',
#    'P'],
#   ['1777',
#    'SIARGAO ISLAND MEDICAL CENTER',
#    '50',
#    'INF/DISP',
#    '09505362182/\n09319231856',
#    'siargaodh@gmail.com',
#    'BRGY. I,',
#    'DAPA',
#    'G'],
#   ['1778',
#    'ST. PAUL SURIGAO UNIVERSITY\nHOSPITAL, INC.',
#    '60',
#    'LEVEL 2',
#    '086 8272647/\n09434288887',
#    'spsuhhr@gmail.com',
#    'NATIONAL HIGHWAY, KM. 4,\nBRGY. LUNA,',
#    'SURIGAO CITY',
#    'P'],
#   ['1779',
#    'SURIGAO DEL NORTE PROVINCIAL\nHOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09989999530',
#    'sdnph2014@gmail.com',
#    'BRGY. STA. CRUZ,',
#    'PLACER',
#    'G'],
#   ['1780',
#    "SURIGAO DOCTORS' HOSPITAL, INC.",
#    '50',
#    'LEVEL 1',
#    '09501757169',
#    'surigaodoctors@gmail.com',
#    'SITIO KINABUTAN, BRGY. RIZAL,',
#    'SURIGAO CITY',
#    'P'],
#   ['1781',
#    'SURIGAO MEDICAL CENTER, INC',
#    '50',
#    'LEVEL 1',
#    '086 8262004',
#    'surigaomedicalcenter@yahoo.co\nm',
#    'KM. 1, NATIONAL HIGHWAY,\nBRGY. WASHINGTON,',
#    'SURIGAO CITY',
#    'P'],
#   ['SURIGAO DEL SUR', None, None, None, None, None, None, None, None]],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['1782',
#    'ADELA SERRA TY MEMORIAL\nMEDICAL CENTER',
#    '200',
#    'LEVEL 2',
#    '0917-1280977',
#    'astmmc2021@gmail.com',
#    'CAPITOL HILLS, TELAJE,',
#    'TANDAG',
#    'G'],
#   ['1783',
#    'ANDRES SORIANO MEMORIAL\nHOSPITAL COOPERATIVE',
#    '75',
#    'LEVEL 2',
#    '086 8533124',
#    'asmhc97@yahoo.com',
#    'PUROK 1, BRGY. CUMAWAS,',
#    'BISLIG',
#    'P'],
#   ['1784',
#    'BISLIG DISTRICT HOSPITAL',
#    '50',
#    'LEVEL 1',
#    '086 8536008/\n09338692038',
#    'bdh_bislig@yahoo.com',
#    'NATIONAL HIGHWAY,\nPOBLACION,',
#    'BISLIG',
#    'G'],
#   ['1785',
#    'CARRASCAL PRIMARY HEALTH CARE\nFACILITY',
#    '26',
#    'INF/DISP',
#    '09982543035',
#    'cphcfofficial@gmail.com',
#    'TRUGILLO-CULTURAL STREETS,\nBAYBAY,',
#    'CARRASCAL',
#    'G'],
#   ['1786',
#    'CORTES MUNICIPAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09480550881/09121783\n351 (HOF)',
#    'cortesmunhosp1995@gmail.co\nm',
#    'SITIO BANUISON, BURGOS,',
#    'CORTES',
#    'G'],
#   ['1787',
#    'F.P. URBIZTONDO MEDICAL\nHOSPITAL, INC.',
#    '20',
#    'INF/DISP',
#    '09193153744/091931837\n44',
#    'fpummhi@gmail.com',
#    'NATIONAL HIGHWAY,\nPOBLACION,',
#    'BAROBO',
#    'P'],
#   ['1788',
#    'HINATUAN DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09184806892',
#    'hinatuandistricthospital74@gm\nail.com',
#    'LACASA,',
#    'HINATUAN',
#    'G'],
#   ['1789',
#    'LIANGA DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09394774254',
#    'liangadistricthospital@yahoo.co\nm',
#    'PUROK I, POBLACION,',
#    'LIANGA',
#    'G'],
#   ['1790',
#    'LINGIG COMMUNITY HOSPITAL',
#    '15',
#    'INF/DISP',
#    '09173184321',
#    'lingigcommunityhospital@yaho\no.com',
#    'PUROK 2A, PEÑANUEVA ST.,\nPOBLACION,',
#    'LINGIG',
#    'G'],
#   ['1791',
#    'MADRID DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '086\n2134160/09985777809',
#    'madrid_dh@yahoo.com',
#    'NATIONAL HIGHWAY,\nBARANGAY QUIRINO,',
#    'MADRID',
#    'G'],
#   ['1792',
#    'MARIHATAG DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09304069069/\n09630701175',
#    'mdhmsds@gmail.com',
#    'PAGBAHANAN II, POBLACION,',
#    'MARIHATAG',
#    'G'],
#   ['1793',
#    'SAN MIGUEL COMMUNITY HOSPITAL',
#    '14',
#    'INF/DISP',
#    '086 2146017;\n09988571367',
#    'sanmiguelcommunityhospital@\ngmail.com',
#    'PUROK 8, TINA,',
#    'SAN MIGUEL',
#    'G'],
#   ['BANGSAMORO AUTONOMOUS REGION OF MUSLIM MINDANAO',
#    None,
#    None,
#    None,
#    None,
#    '',
#    None,
#    None,
#    None],
#   ['BASILAN', None, None, None, None, None, None, None, None],
#   ['1794',
#    'BASILAN GENERAL HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09177040524 /\n09189069299',
#    'bghphihealth@gmail.com',
#    'KM. 2, BINUANGAN',
#    'ISABELA',
#    'G'],
#   ['1795',
#    'DR. JOSE MA. TORRES MEMORIAL\nFOUNDATION HOSPITAL, INC.',
#    '21',
#    'INF/DISP',
#    '09062044115/093615271\n81',
#    'jmthospmeridianph@yahoo.co\nm',
#    'DR. TORRES ST.,',
#    'LAMITAN',
#    'P'],
#   ['1796',
#    'EDIBORAH P. YAP MEMORIAL\nHOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09176987767',
#    'epymh@yahoo.com',
#    'BRGY. LIMO-OK,',
#    'LAMITAN',
#    'G'],
#   ['1797',
#    'INFANTE HOSPITAL MANAGEMENT\nCORPORATION',
#    '25',
#    'LEVEL 1',
#    '09177043022',
#    'infantehospital@yahoo.com',
#    'C.P. GARCIA ST.,',
#    'ISABELA',
#    'P'],
#   ['1798',
#    'JUAN S. ALANO MEMORIAL\nHOSPITAL, INC.',
#    '25',
#    'LEVEL 1',
#    '(062)200-32-72 /\n09178243281',
#    'alanohospital@yahoo.com.ph',
#    'RIZAL AVE.,',
#    'ISABELA',
#    'P'],
#   ['1799',
#    'SUMISIP DISTRICT HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09176767125',
#    'sumusipdistricthospital@gmail.\ncom',
#    'BULI-BULI',
#    'SUMISIP',
#    'G'],
#   ['COTABATO CITY', None, None, None, None, None, None, None, None]],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['1800',
#    'COTABATO MEDICAL SPECIALIST\nHOSPITAL',
#    '25',
#    'LEVEL 1',
#    '064-421-4145',
#    'cotmedspec@yahoo.com.ph',
#    'QUEZON AVENUE, ROSARY\nHEIGHTS - 11',
#    'COTABATO CITY',
#    'P'],
#   ['1801',
#    'COTABATO PUERICULTURE CENTER\nAND GENERAL HOSPITAL\nFOUNDATION, INC.',
#    '30',
#    'LEVEL 1',
#    '(064)421-7323 / 064-421-\n2369 / 09165344115',
#    'cotabatopuericulture@yahoo.co\nm',
#    '035 DON RUFINO ALONZO ST.,\nPOBLACION 6',
#    'COTABATO CITY',
#    'P'],
#   ['1802',
#    'COTABATO REGIONAL AND MEDICAL\nCENTER',
#    '375',
#    'LEVEL 3',
#    '421-2192',
#    'crmc_12@yahoo.com',
#    'SINSUAT AVE.,',
#    'COTABATO CITY',
#    'G'],
#   ['1803',
#    'EROS MEDICAL CLINIC',
#    '18',
#    'INF/DISP',
#    '(064) 425-\n5048/09175483733',
#    'erosmccot19@gmail.com',
#    'TAMONTAKA I',
#    'COTABATO CITY',
#    'P'],
#   ['1804',
#    'NOTRE DAME HOSPITAL AND SIENA\nCOLLEGE OF COTABATO, INC.',
#    '40',
#    'LEVEL 2',
#    '(064-421-2954 . 064-421-\n2243',
#    'ndhospital@yahoo.com',
#    'SINSUAT AVENUE, ROSARY\nHEIGHTS IX,',
#    'COTABATO CITY',
#    'P'],
#   ['1805',
#    'UNITED DOCTORS HOSPITAL OF\nCOTABATO CITY, INC.',
#    '24',
#    'LEVEL 1',
#    '064 421 3711/\n091754206679',
#    'udhcci@gmail.com',
#    'ND AVE., IMMACULATE\nCONCEPCION, ROSARY HEIGHTS\n2',
#    'COTABATO CITY',
#    'P'],
#   ['LANAO DEL SUR', None, None, None, None, None, None, None, None],
#   ['1806',
#    'AMAI PAKPAK MEDICAL CENTER',
#    '438',
#    'LEVEL 3',
#    '09178990640',
#    'apmc_marawi@yahoo.com',
#    'BO. DATU SABER, 9700',
#    'MARAWI CITY',
#    'G'],
#   ['1807',
#    'BALINDONG MUNICIPAL HOSPITAL',
#    '10',
#    'LEVEL 1',
#    '09171506029',
#    'balindongmunicipalhospital@ya\nhoo.com',
#    'BRGY. SALIPONGAN',
#    'BALINDONG (WATU)',
#    'G'],
#   ['1808',
#    'DR. ABDULLAH HOSPITAL\nFOUNDATION INC.',
#    '30',
#    'LEVEL 1',
#    '09175858021',
#    'dr.abdullahhospital@gmail.com',
#    'NEW CAPITOL, BRGY. MARAWI,',
#    'MARAWI CITY',
#    'P'],
#   ['1809',
#    'DR. SERAPIO B. MONTAÑER JR., AL-\nHAJ MEMORIAL HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '0917-321-4935',
#    'dsbmmh1121@gmail.com',
#    'LUMPONG',
#    'MALABANG',
#    'G'],
#   ['1810',
#    'HIJRAH INFIRMARY',
#    '5',
#    'INF/DISP',
#    '09272289577',
#    'hijrahhospital@gmail.com',
#    '35 BAGUINDALI ST., BRGY.\nMARAWI POB.,',
#    'MARAWI CITY',
#    'P'],
#   ['1811',
#    'MARAWI MIDTOWN INFIRMARY',
#    '10',
#    'INF/DISP',
#    '09559302852',
#    'buadiheart@gmail.com',
#    'AMAI PAKPAK AVENUE, BASAK\nMALUTLUT',
#    'MARAWI CITY',
#    'P'],
#   ['1812',
#    'MINDALANO SPECIALIST HOSPITAL\nFOUNDATION, INC.',
#    '50',
#    'LEVEL 1',
#    '09087584496 /\n09275221542',
#    'tahir_mindalano@yahoo.com.p\nh',
#    'PANGGAO, SADUC PROPER',
#    'MARAWI CITY',
#    'P'],
#   ['1813',
#    'RANAO FAMILY MEDICAL CLINIC',
#    '12',
#    'INF/DISP',
#    '09172734706',
#    'muslimah_masorong@yahoo.co\nm',
#    '092 PANGGAO SADUC',
#    'MARAWI CITY',
#    'P'],
#   ['1814',
#    'SALAAM HOSPITAL FOUNDATION,\nINC.',
#    '30',
#    'LEVEL 1',
#    '09177180675',
#    'salaamhospital08@gmail.com',
#    'BRGY PAPANDAYAN',
#    'MARAWI CITY',
#    'P'],
#   ['1815',
#    'TAMPARAN DISTRICT HOSPITAL',
#    '100',
#    'LEVEL 1',
#    '063-221-3823',
#    'tdh.hospital@gmail.com',
#    'POBLACION',
#    'TAMPARAN',
#    'G'],
#   ['1816',
#    'UNAYAN MUNICIPAL HOSPITAL',
#    '10',
#    'LEVEL 1',
#    '09198666665',
#    'raquelbenito48@yahoo.com',
#    'BGRY. PAGALAMATAN,',
#    'BINIDAYAN',
#    'G'],
#   ['1817',
#    'WAO DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09778368176',
#    'wdhcare@yahoo.com',
#    'WESTERN',
#    'WAO',
#    'G'],
#   ['MAGUINDANAO', None, None, None, None, None, None, None, None],
#   ['1818',
#    'ABPI-SAMAMA MEDICAL LYING-IN\nCLINIC AND HOSPITAL',
#    '12',
#    'INF/DISP',
#    '09178662872',
#    'abpisamama@gmail.com',
#    'BUAYAN',
#    'DATU PIANG',
#    'P']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['1819',
#    'BULUAN DISTRICT HOSPITAL',
#    '100',
#    'LEVEL 1',
#    '09666617191',
#    'buluandistricthospital.phic@gm\nail.com',
#    'NATIONAL HIGHWAY\nPOBLACION',
#    'BULUAN',
#    'G'],
#   ['1820',
#    'CAMP BRIG. GEN. SALIPADA K.\nPENDATUN HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09155652062',
#    'rhsarmm@.gmaill.com',
#    'CAMP BGEN. SALIPADA\nPENDATUN',
#    'PARANG',
#    'G'],
#   ['1821',
#    'CAMP SIONGCO STATION HOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09669142349',
#    'cssh_sixid@yahoo.com',
#    'CAMP SIONGCO, AWANG',
#    'DATU ODIN SINSUAT',
#    'G'],
#   ['1822',
#    'COTABATO SANITARIUM AND\nGENERAL HOSPITAL',
#    '140',
#    'LEVEL 1',
#    '(064)-429-0082',
#    'cotsan_1976@yahoo.com',
#    'BRGY. UNGAP,',
#    'SULTAN KUDARAT\n(NULING)',
#    'G'],
#   ['1823',
#    'DATU BLAH T. SINSUAT DISTRICT\nHOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09088730305',
#    'datublah@gmail.com',
#    'NURO',
#    'UPI',
#    'G'],
#   ['1824',
#    'DATU ODIN SINSUAT DISTRICT\nHOSPITAL',
#    '50',
#    'LEVEL 1',
#    '09176223894',
#    'dinaigmun.hospital@gmail.com',
#    'POBLACION DALICAN,',
#    'DATU ODIN SINSUAT',
#    'G'],
#   ['1825',
#    "DOC SWEET'S MATERNAL AND\nCHILDREN'S HOSPITAL",
#    '10',
#    'INF/DISP',
#    '09175706297',
#    'dsmchgang@yahoo.com',
#    'GANG',
#    'SULTAN KUDARAT\n(NULING)',
#    'P'],
#   ['1826',
#    'DR. G. AKAS HOSPITAL, INC.',
#    '10',
#    'INF/DISP',
#    '09670019036',
#    'drgakashospitalinc@gmail.com',
#    'KITANGO',
#    'DATU SAUDI-\nAMPATUAN',
#    'P'],
#   ['1827',
#    'EROS HOSPITAL',
#    '23',
#    'LEVEL 1',
#    '09175100873',
#    'eroshospital@gmail.com',
#    'LAWAN ST., POBLACION',
#    'DATU PAGLAS',
#    'P'],
#   ['1828',
#    "GUINDULUNGAN DOCTOR'S CLINIC &\nINFIRMARY",
#    '33',
#    'INF/DISP',
#    '09176243356',
#    'guindudoc@gmail.com',
#    'TAMBUNAN II',
#    'GUINDULUNGAN',
#    'P'],
#   ['1829',
#    'IRANUN DISTRICT HOSPITAL',
#    '25',
#    'INF/DISP',
#    '(064) 4218 057',
#    'idh.barmm@gmail.com',
#    'NOTRE DAME SITE, POBLACION 1',
#    'PARANG',
#    'G'],
#   ['1830',
#    'MAGRIÑA CLINIC AND HOSPITAL',
#    '20',
#    'INF/DISP',
#    '09153440529',
#    'jaymagriña@yahoo.com',
#    'SAMPAGUITA ST., POBLACION',
#    'BULUAN',
#    'P'],
#   ['1831',
#    'MAGUINDANAO PROVINCIAL\nHOSPITAL',
#    '299',
#    'LEVEL 2',
#    '09152595708',
#    'iphomaguindanao.mph@gmail.\ncom',
#    'LIMPONGO',
#    'DATU HOFFER\nAMPATUAN',
#    'G'],
#   ['1832',
#    'MANANGAN CLINIC AND HOSPITAL',
#    '25',
#    'INF/DISP',
#    '09155824455',
#    'serg_manangan@yahoo.com',
#    'SAMPAGUITA ST., POBLACION',
#    'BULUAN',
#    'P'],
#   ['1833',
#    'SOUTH UPI MUNICIPAL HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09053525675',
#    'southupi.municipalhospital@ya\nhoo.com',
#    'ROMONGAOB,',
#    'SOUTH UPI',
#    'G'],
#   ['1834',
#    'SULAIK CLINIC AND HOSPITAL',
#    '30',
#    'LEVEL 1',
#    '09052634225',
#    'sulaikclinicandhospital@gmail.c\nom',
#    'PUROK MALINIS, BRGY.\nPOBLACION',
#    'MAGANOY',
#    'P'],
#   ['SULU', None, None, None, None, None, None, None, None],
#   ['1835',
#    'LUUK DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09171039539',
#    'luukdistricthospital10@gmail.co\nm',
#    'TUBIG PUTIH',
#    'LUUK',
#    'G'],
#   ['1836',
#    'PANAMAO DISTRICT HOSPITAL',
#    '25',
#    'INF/DISP',
#    '09982891338',
#    'ppanamaodistricthospital@yaho\no.com',
#    'SEIT LAKE',
#    'OLD PANAMAO',
#    'G'],
#   ['1837',
#    'PARANG DISTRICT HOSPITAL',
#    '25',
#    'LEVEL 1',
#    '09175059987',
#    'cubejake@gmail.com',
#    'KANAWAY',
#    'PARANG',
#    'G'],
#   ['1838',
#    'SIASI DISTRICT HOSPITAL',
#    '25',
#    'INF/DISP',
#    '09177225581',
#    'siasidistricthospital2019@gmail\n.com',
#    'CAMPO ISLAM',
#    'SIASI',
#    'G']],
#  [['',
#    'NAME OF HEALTH FACILITY',
#    'BEDS',
#    'CAT',
#    'TEL_NO',
#    'EMAIL',
#    'STREET',
#    'MUNICIPALITY',
#    'SEC'],
#   ['1839',
#    'SULU PROVINCIAL HOSPITAL',
#    '100',
#    'LEVEL 1',
#    '091777111300',
#    'iphosulu@gmail.com',
#    'IPHO-ASTURIAS ST.,',
#    'JOLO',
#    'G'],
#   ['1840',
#    'SULU SANITARIUM AND GENERAL\nHOSPITAL',
#    '75',
#    'LEVEL 1',
#    '09173258520',
#    'sulusanitarium@yahoomail.com',
#    'UPPER SAN RAYMUNDO,',
#    'JOLO',
#    'G'],
#   ['TAWI-TAWI', None, None, None, None, None, None, None, None],
#   ['1841',
#    "BONGAO DOCTORS' HOSPITAL",
#    '12',
#    'INF/DISP',
#    '(068)268-1535',
#    'bongaodoctorshospital@yahoo.c\nom',
#    'ILMOH STREET, TUBIG\nMAMPALLAM',
#    'BONGAO',
#    'P'],
#   ['1842',
#    'CAGAYAN DE TAWI-TAWI DISTRICT\nHOSPITAL',
#    '25',
#    'INF/DISP',
#    '09179937830',
#    'cagayandetawidistrict-\nhospital@gmail.com',
#    'LUPA PULA',
#    'CAGAYAN DE TAWI-\nTAWI (MAPUN)',
#    'G'],
#   ['1843',
#    'DATU ALAWADDIN T. BANDON\nMEMORIAL HOSPITAL',
#    '10',
#    'INF/DISP',
#    '09173004182',
#    'sibutuhospitall@gmail.com',
#    'BRGY. HADJI BIDIN, POBLACION,\n(SIBUTU)',
#    'SIBURU',
#    'G'],
#   ['1844',
#    'DATU HALUN SAKILAN MEMORIAL\nHOSPITAL',
#    '50',
#    'LEVEL 1',
#    '0949-999-7000',
#    'phic.dhsmhofficial@gmail.com',
#    'LAMION,',
#    'BONGAO',
#    'G'],
#   ['1845',
#    'HOLY FAMILY HOSPITAL',
#    '12',
#    'INF/DISP',
#    '(062) 268-1271',
#    'hfh.avj@gmail.com',
#    'LAGUERRE ST.,',
#    'BONGAO',
#    'P'],
#   ['1846',
#    'TUAN LIGADDUNG LIPAE MEMORIAL\nHOSPITAL',
#    '25',
#    'INF/DISP',
#    '09982588567',
#    'docali2015@yahoo.com',
#    'POBLACION,',
#    'SAPA-SAPA',
#    'G']]]

# %%
# I think we can turn this into a dataframe

if tables:
    df = pd.DataFrame(tables[0])
else:
    print("No tables in the PDF")

#display
df.head(10)
# Out:
#                                   0  \
# 0
# 1  CORDILLERA ADMINISTRATIVE REGION
# 2                              ABRA
# 3                                 1
# 4                                 2
# 5                                 3
# 6                                 4
# 7                                 5
# 8                                 6
# 9                                 7
#
#                                                 1     2         3  \
# 0                         NAME OF HEALTH FACILITY  BEDS       CAT
# 1                                            None  None      None
# 2                                            None  None      None
# 3                        ABRA PROVINCIAL HOSPITAL    50   LEVEL 1
# 4                        ASSUMPTA FAMILY HOSPITAL    17   LEVEL 1
# 5                      BANGUED CHRISTIAN HOSPITAL    17   LEVEL 1
# 6  DR. PETRONILO V. SEARES SR.\nMEMORIAL HOSPITAL    24   LEVEL 1
# 7                        LA PAZ DISTRICT HOSPITAL    12  INF/DISP
# 8                     ST. THERESA WELLNESS CENTER    12  INF/DISP
# 9                         VALERA MEDICAL HOSPITAL    15  INF/DISP
#
#                             4                                        5  \
# 0                      TEL_NO                                    EMAIL
# 1                        None
# 2                        None                                     None
# 3                  0747527509    abraprovincialhospital@yahoo.c\nom.ph
# 4                 09177997644                assumpta_815@yahoo.com.ph
# 5                  0747525644  banguedchristianhospital@yaho\no.com.ph
# 6  09353388157 /\n09677608595          petronilo_seares@yahoo.com.p\nh
# 7                 09273096506                    lpdhpho.pga@gmail.com
# 8                 09778268084      sttheresawellnesscenter@gmail.\ncom
# 9                  0747255595           valeramed_hospital@yahoo.co\nm
#
#                              6             7     8
# 0                       STREET  MUNICIPALITY   SEC
# 1                         None          None  None
# 2                         None          None  None
# 3  CAPITULACION STREET, CALABA       BANGUED     G
# 4       MAGALLANES ST., ZONE 5       BANGUED     P
# 5      TORRIJOS STREET, ZONE 5       BANGUED     P
# 6       PEÑARRUBIA ST., ZONE 4       BANGUED     P
# 7                    POBLACION        LA PAZ     G
# 8            BARANGAY TALOGTOG       DOLORES     P
# 9         RIZAL STREET, ZONE 7       BANGUED     P

# %%
# I noticed that there are rows that divide the dataframe into regions.
# I don't really need it though. Let's use a for loop that will drop rows with 'None' values

df_drops=df.dropna(thresh=df.shape[1]-2)
df_drops
# Out:
#      0                                                  1     2         3  \
# 0                                 NAME OF HEALTH FACILITY  BEDS       CAT
# 3    1                           ABRA PROVINCIAL HOSPITAL    50   LEVEL 1
# 4    2                           ASSUMPTA FAMILY HOSPITAL    17   LEVEL 1
# 5    3                         BANGUED CHRISTIAN HOSPITAL    17   LEVEL 1
# 6    4     DR. PETRONILO V. SEARES SR.\nMEMORIAL HOSPITAL    24   LEVEL 1
# 7    5                           LA PAZ DISTRICT HOSPITAL    12  INF/DISP
# 8    6                        ST. THERESA WELLNESS CENTER    12  INF/DISP
# 9    7                            VALERA MEDICAL HOSPITAL    15  INF/DISP
# 10   8      VILLAVICIOSA MEDICARE AND\nCOMMUNITY HOSPITAL    12  INF/DISP
# 12   9                      AMMA JADSAC DISTRICT HOSPITAL    18  INF/DISP
# 13  10                           APAYAO DISTRICT HOSPITAL    12  INF/DISP
# 14  11                         APAYAO PROVINCIAL HOSPITAL    12  INF/DISP
# 15  12                           CONNER DISTRICT HOSPITAL    25   LEVEL 1
# 16  13  FAR NORTH LUZON GENERAL\nHOSPITAL AND TRAINING...   164   LEVEL 2
# 17  14                            FLORA DISTRICT HOSPITAL    12  INF/DISP
# 18  15                     STA. MARCELA DISTRICT HOSPITAL    12  INF/DISP
# 20  16                             ATOK DISTRICT HOSPITAL    15   LEVEL 1
# 21  17        BAGUIO GENERAL HOSPITAL AND\nMEDICAL CENTER   600   LEVEL 3
#
#                              4                                            5  \
# 0                       TEL_NO                                        EMAIL
# 3                   0747527509        abraprovincialhospital@yahoo.c\nom.ph
# 4                  09177997644                    assumpta_815@yahoo.com.ph
# 5                   0747525644      banguedchristianhospital@yaho\no.com.ph
# 6   09353388157 /\n09677608595              petronilo_seares@yahoo.com.p\nh
# 7                  09273096506                        lpdhpho.pga@gmail.com
# 8                  09778268084          sttheresawellnesscenter@gmail.\ncom
# 9                   0747255595               valeramed_hospital@yahoo.co\nm
# 10                 09168911087               vmchospital2008@yahoo.com.p\nh
# 12                 09161292808                      ajdh.hospital@gmail.com
# 13                 09353581439                       adhcalanasan@yahoo.com
# 14                 09457715427                        aph_kabugao@yahoo.com
# 15                 09952093932           connerdistricthospital@yahoo.c\nom
# 16                  0746340074                         fnlghtc@yahoo.com.ph
# 17                 09287301508                      floradisthosp@gmail.com
# 18                 09177703602  smdh1975@gmail.com /\nsmdh1975@yahoo.com.ph
# 20                 09209507875                        benguet_adh@yahoo.com
# 21                  0746617932                         mcc@bghmc.doh,gov.ph
#
#                                      6                  7    8
# 0                               STREET       MUNICIPALITY  SEC
# 3          CAPITULACION STREET, CALABA            BANGUED    G
# 4               MAGALLANES ST., ZONE 5            BANGUED    P
# 5              TORRIJOS STREET, ZONE 5            BANGUED    P
# 6               PEÑARRUBIA ST., ZONE 4            BANGUED    P
# 7                            POBLACION             LA PAZ    G
# 8                    BARANGAY TALOGTOG            DOLORES    P
# 9                 RIZAL STREET, ZONE 7            BANGUED    P
# 10                            AP-APAYA       VILLAVICIOSA    G
# 12                  BARANGAY POBLACION             PUDTOL    G
# 13               ABASAG ST., POBLACION  CALANASAN (BAYAG)    G
# 14  DUCRAO STREET, BARANGAY\nPOBLACION            KABUGAO    G
# 15                              RIPANG             CONNER    G
# 16                       BRGY. QUIRINO               LUNA    G
# 17                            BAGUTONG              FLORA    G
# 18                          SAN CARLOS       STA. MARCELA    G
# 20                     SAYANGAN, PAOAY               ATOK    G
# 21                 GOVERNOR PACK ROAD,        BAGUIO CITY    G

# %%
#melt the wide table and what remains is column index 1 (name of hospital), 
#combined index of [6,7] (location) and index
#4 (contact number)

# Let's get Column 1 first.

name = df_drops[1]
name
# Out:
# 0                               NAME OF HEALTH FACILITY
# 3                              ABRA PROVINCIAL HOSPITAL
# 4                              ASSUMPTA FAMILY HOSPITAL
# 5                            BANGUED CHRISTIAN HOSPITAL
# 6        DR. PETRONILO V. SEARES SR.\nMEMORIAL HOSPITAL
# 7                              LA PAZ DISTRICT HOSPITAL
# 8                           ST. THERESA WELLNESS CENTER
# 9                               VALERA MEDICAL HOSPITAL
# 10        VILLAVICIOSA MEDICARE AND\nCOMMUNITY HOSPITAL
# 12                        AMMA JADSAC DISTRICT HOSPITAL
# 13                             APAYAO DISTRICT HOSPITAL
# 14                           APAYAO PROVINCIAL HOSPITAL
# 15                             CONNER DISTRICT HOSPITAL
# 16    FAR NORTH LUZON GENERAL\nHOSPITAL AND TRAINING...
# 17                              FLORA DISTRICT HOSPITAL
# 18                       STA. MARCELA DISTRICT HOSPITAL
# 20                               ATOK DISTRICT HOSPITAL
# 21          BAGUIO GENERAL HOSPITAL AND\nMEDICAL CENTER
# Name: 1, dtype: object

# %%
# Next lets get column 6 and 7 and combine them together
street = df_drops[6]
muni = df_drops[7]
street
# Out:
# 0                                 STREET
# 3            CAPITULACION STREET, CALABA
# 4                 MAGALLANES ST., ZONE 5
# 5                TORRIJOS STREET, ZONE 5
# 6                 PEÑARRUBIA ST., ZONE 4
# 7                              POBLACION
# 8                      BARANGAY TALOGTOG
# 9                   RIZAL STREET, ZONE 7
# 10                              AP-APAYA
# 12                    BARANGAY POBLACION
# 13                 ABASAG ST., POBLACION
# 14    DUCRAO STREET, BARANGAY\nPOBLACION
# 15                                RIPANG
# 16                         BRGY. QUIRINO
# 17                              BAGUTONG
# 18                            SAN CARLOS
# 20                       SAYANGAN, PAOAY
# 21                   GOVERNOR PACK ROAD,
# Name: 6, dtype: object

# %%
muni
# Out:
# 0          MUNICIPALITY
# 3               BANGUED
# 4               BANGUED
# 5               BANGUED
# 6               BANGUED
# 7                LA PAZ
# 8               DOLORES
# 9               BANGUED
# 10         VILLAVICIOSA
# 12               PUDTOL
# 13    CALANASAN (BAYAG)
# 14              KABUGAO
# 15               CONNER
# 16                 LUNA
# 17                FLORA
# 18         STA. MARCELA
# 20                 ATOK
# 21          BAGUIO CITY
# Name: 7, dtype: object

# %%
# use concatenation
location = street.fillna('') + ' | ' + muni.fillna('')
df_drops['location'] = location

location
# Out:
# C:\Users\ryzek\AppData\Local\Temp\ipykernel_11188\982270020.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_drops['location'] = location
# 0                            STREET | MUNICIPALITY
# 3            CAPITULACION STREET, CALABA | BANGUED
# 4                 MAGALLANES ST., ZONE 5 | BANGUED
# 5                TORRIJOS STREET, ZONE 5 | BANGUED
# 6                 PEÑARRUBIA ST., ZONE 4 | BANGUED
# 7                               POBLACION | LA PAZ
# 8                      BARANGAY TALOGTOG | DOLORES
# 9                   RIZAL STREET, ZONE 7 | BANGUED
# 10                         AP-APAYA | VILLAVICIOSA
# 12                     BARANGAY POBLACION | PUDTOL
# 13       ABASAG ST., POBLACION | CALANASAN (BAYAG)
# 14    DUCRAO STREET, BARANGAY\nPOBLACION | KABUGAO
# 15                                 RIPANG | CONNER
# 16                            BRGY. QUIRINO | LUNA
# 17                                BAGUTONG | FLORA
# 18                       SAN CARLOS | STA. MARCELA
# 20                          SAYANGAN, PAOAY | ATOK
# 21               GOVERNOR PACK ROAD, | BAGUIO CITY
# dtype: object

# %%
#last column: contact number
contact_no = df_drops[4]

contact_no
# Out:
# 0                         TEL_NO
# 3                     0747527509
# 4                    09177997644
# 5                     0747525644
# 6     09353388157 /\n09677608595
# 7                    09273096506
# 8                    09778268084
# 9                     0747255595
# 10                   09168911087
# 12                   09161292808
# 13                   09353581439
# 14                   09457715427
# 15                   09952093932
# 16                    0746340074
# 17                   09287301508
# 18                   09177703602
# 20                   09209507875
# 21                    0746617932
# Name: 4, dtype: object

# %%
fin = pd.DataFrame({
    'Hospital Name': name,
    'Location': location,
    'Contact Number/s.': contact_no
})
# removing row 0 because it is unecessary
fin = fin.drop(0)
#since the dataframe will start at index 3, we reset the row indices

fin.reset_index(drop=True, inplace=True)

# %%
fin
# Out:
#                                         Hospital Name  \
# 0                            ABRA PROVINCIAL HOSPITAL
# 1                            ASSUMPTA FAMILY HOSPITAL
# 2                          BANGUED CHRISTIAN HOSPITAL
# 3      DR. PETRONILO V. SEARES SR.\nMEMORIAL HOSPITAL
# 4                            LA PAZ DISTRICT HOSPITAL
# 5                         ST. THERESA WELLNESS CENTER
# 6                             VALERA MEDICAL HOSPITAL
# 7       VILLAVICIOSA MEDICARE AND\nCOMMUNITY HOSPITAL
# 8                       AMMA JADSAC DISTRICT HOSPITAL
# 9                            APAYAO DISTRICT HOSPITAL
# 10                         APAYAO PROVINCIAL HOSPITAL
# 11                           CONNER DISTRICT HOSPITAL
# 12  FAR NORTH LUZON GENERAL\nHOSPITAL AND TRAINING...
# 13                            FLORA DISTRICT HOSPITAL
# 14                     STA. MARCELA DISTRICT HOSPITAL
# 15                             ATOK DISTRICT HOSPITAL
# 16        BAGUIO GENERAL HOSPITAL AND\nMEDICAL CENTER
#
#                                         Location           Contact Number/s.
# 0          CAPITULACION STREET, CALABA | BANGUED                  0747527509
# 1               MAGALLANES ST., ZONE 5 | BANGUED                 09177997644
# 2              TORRIJOS STREET, ZONE 5 | BANGUED                  0747525644
# 3               PEÑARRUBIA ST., ZONE 4 | BANGUED  09353388157 /\n09677608595
# 4                             POBLACION | LA PAZ                 09273096506
# 5                    BARANGAY TALOGTOG | DOLORES                 09778268084
# 6                 RIZAL STREET, ZONE 7 | BANGUED                  0747255595
# 7                        AP-APAYA | VILLAVICIOSA                 09168911087
# 8                    BARANGAY POBLACION | PUDTOL                 09161292808
# 9      ABASAG ST., POBLACION | CALANASAN (BAYAG)                 09353581439
# 10  DUCRAO STREET, BARANGAY\nPOBLACION | KABUGAO                 09457715427
# 11                               RIPANG | CONNER                 09952093932
# 12                          BRGY. QUIRINO | LUNA                  0746340074
# 13                              BAGUTONG | FLORA                 09287301508
# 14                     SAN CARLOS | STA. MARCELA                 09177703602
# 15                        SAYANGAN, PAOAY | ATOK                 09209507875
# 16             GOVERNOR PACK ROAD, | BAGUIO CITY                  0746617932

# %%
fin.to_csv('hospitals.csv',index=False)
print("Completed")
# Out:
# Completed

# %% [markdown]
# 7.2 Conclusion:

# %% [markdown]
# I learned how to use Pandas more extensively to create my own Data Frame which is basic data cleaning. As someone
